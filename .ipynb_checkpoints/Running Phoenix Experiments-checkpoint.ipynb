# %% [markdown]
# ## Set up the Phoenix connection and establish a test dataset
# ### Connects to Phoenix

# %%
import os
os.environ.pop("ALL_PROXY", None)
os.environ.pop("all_proxy", None)
from dotenv import load_dotenv
load_dotenv()
os.environ["PHOENIX_CLIENT_HEADERS"] = f"api_key={os.getenv('PHOENIX_API_KEY')}"
os.environ["PHOENIX_COLLECTOR_ENDPOINT"] = "https://app.phoenix.arize.com/s/linkedInArticleGen"

from phoenix.otel import register
register(project_name="linkedInArticleGen")

from phoenix.client import Client
client = Client()
print("Connected to Phoenix")

# %% [markdown]
# ### Initiate new dataset (only needs running once when starting new dataset)
# Read the transcript from Class 4 from a local file, then creates a dataset in Phoenix with that transcript stored as a re-usable test set.
#
# Later experiments will feed this test case for later tests for objective comparison of outputs.
#
# *One time*

# %%
## Read the dataset
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

## Creates a dataset with the given name and stored experiment
dataset = client.datasets.create_dataset(
    name="initial_test_from_Class_4",
    dataset_description="Lecture transcripts and articles from class 4 for testing initial batch of prompts",
    examples=[
        {
            "input": {"raw_material": raw_material},
            "output": {},
            "metadata": {"source": "class 4 transcript"}
        }
    ]
)
print(f"Created dataset: {dataset.id}")

# %% [markdown]
# ### Run old dataset

# %%
# Load existing dataset (already created in Phoenix)
dataset = client.datasets.get_dataset(dataset="initial_test_from_Class_4")
print(f"Loaded dataset: {dataset.id}")

# %% [markdown]
# # Run the experiment for angleProposalPrompt1.md
# ## Run the experiment and store the output

# %%
# Load the Phoenix experiment runner
from phoenix.client.experiments import run_experiment
from datetime import datetime
import anthropic

# Helper to read prompt files from the prompts/ folder
def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

# Load current angle proposal prompt (re-reads from file each time so edits are picked up)
angle_prompt = read_prompt("angleProposalPrompt1.md")

# Define the task — Phoenix runs this against each example in the dataset
def angle_proposal_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

# Auto-generate unique experiment name from timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-{timestamp}"

# Run the experiment
latest_experiment = run_experiment(
    dataset=dataset,
    task=angle_proposal_task,
    experiment_name=experiment_name,
    experiment_description="Auto-run",
    timeout=120
)

print(f"Experiment: {experiment_name}")

# %% [markdown]
# ## Export the experiment in a legible format

# %% [markdown]
# ### Export the prompt sys message

# %%
# See what was sent to the API as the system prompt
print("=" * 60)
print("SYSTEM PROMPT:")
print("=" * 60)
print(angle_prompt)

# %% [markdown]
# ### For exporting the user message

# %%
# See the input that was sent as the user message
print("=" * 60)
print("USER MESSAGE (first 500 chars):")
print("=" * 60)
print(raw_material[:500])

# %% [markdown]
# ### For exporting a single experiment output

# %%
# Pull the latest experiment results in a readable format
for run in latest_experiment["task_runs"]:
    print("=" * 60)
    print("OUTPUT:")
    print("=" * 60)
    print(run["output"])
    print("\n\n")

# %% [markdown]
# # Run the experiment up to supervisorPrompt1.5
# ## Run the pipeline up to supervisorPrompt

# %%
import time
import re
from datetime import datetime
from phoenix.client.experiments import run_experiment
import anthropic

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

def extract_final_pitches(output):
    """Extract only the Final Pitches section, stripping all reasoning."""
    marker = "## Final Pitches"
    idx = output.find(marker)
    if idx != -1:
        return output[idx + len(marker):].strip()
    match = re.search(r"##\s*Final\s*Pitches", output, re.IGNORECASE)
    if match:
        return output[match.end():].strip()
    return output.strip()

def full_angle_pipeline(input):
    api_client = anthropic.Anthropic()
    
    # Load prompts
    angle_prompt = read_prompt("angleProposalPrompt1.md")
    supervisor_prompt = read_prompt("supervisorPrompt1.5.md")
    
    # Run angle proposal 3 times, extract only final pitches
    extracted_pitches = []
    for i in range(1, 4):
        print(f"  → Angle proposal {i}/3...")
        if i > 1:
            time.sleep(10)
        message = api_client.messages.create(
            model="claude-opus-4-5-20251101",
            max_tokens=16000,
            system=angle_prompt,
            messages=[{"role": "user", "content": input["raw_material"]}],
        )
        pitches = extract_final_pitches(message.content[0].text)
        extracted_pitches.append(pitches)
        print(f"  ✓ Batch {i} complete")
    
    # Combine extracted pitches into labeled block
    combined = ""
    for i, pitches in enumerate(extracted_pitches, 1):
        combined += f"## Batch {i}\n\n{pitches}\n\n"
    
    # Run supervisor on combined pitches
    print("  → Running supervisor...")
    supervisor_message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=supervisor_prompt,
        messages=[{"role": "user", "content": combined}],
    )
    print("  ✓ Pipeline complete")
    
    return {
        "supervisor_input": combined,
        "supervisor_output": supervisor_message.content[0].text
    }

# ---- CHANGE THIS EACH RUN WHEN NEW DATASET IS EMPLOYED----
run_description = "v1.5 - modded cohesion reviewer 04.06.26"
# --------------------------------

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"full-pipeline-upToSupervisor-{timestamp}"

latest_experiment = run_experiment(
    dataset=dataset,
    task=full_angle_pipeline,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"Experiment: {experiment_name}")
print(f"Description: {run_description}")

# %% [markdown]
# ### Print results for the run above

# %%
for run in latest_experiment["task_runs"]:
    output = run["output"]
    
    # print("=" * 60)
    # print("WHAT THE SUPERVISOR RECEIVED:")
    # print("=" * 60)
    # print(output["supervisor_input"])
    
    # print("\n\n")
    
    print("=" * 60)
    print("WHAT THE SUPERVISOR CHOSE:")
    print("=" * 60)
    print(output["supervisor_output"])

# %%
import sys

# %%
print(sys.executable)

# %% [markdown]
# # Run the experiment for articleGeneratePrompt2.md

# %% [markdown]
# ## Initializing dataset
# (run once)

# %% [markdown]
# ### Load the dataset with samples pitches appended

# %%
# Dataset: raw material + all 3 supervisor-selected pitches
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

pitches = [
    {
        "title": "Make it sound dumber on purpose",
        "style": "Contrarian",
        "pitch": """Apple had the technology to make Siri sound human in 2013 but deliberately made it robotic. User satisfaction rose because expectations dropped. This isn't a quirk — it's a design principle most AI products ignore. The Bing harassment disaster, the catbot spectrum from "as an AI language model" to "meow meow meow" — every point on that range is technically correct, but only one manages expectations for *your* use case. The argument: the AI that sounds slightly mechanical, gives one-sentence answers, and stops short of what's possible will outperform the one that impresses on first contact."""
    },
    {
        "title": "Your bot forces the org chart soul-search",
        "style": "Observation",
        "pitch": """Most companies have never articulated their organizational voice, logic, or relationship posture — it emerged by accident across years of output. Building a chatbot forces the question. The LUX document isn't a branding exercise; it's archaeology. You're discovering what your company actually believes by trying to make a machine embody it. Industrial firms, nonprofits, anyone who's "just doing the work" — they all hit this wall when the bot needs to talk."""
    },
    {
        "title": "Stop iterating on the chat box",
        "style": "Philosopher",
        "pitch": """We're in horseless carriage territory — bolting AI onto document-writing paradigms because that's what we know. The blank text input isn't intimidating because it lacks examples; it's the wrong interface category entirely. The material shows experiments in coordinate-plane text editors, infinite canvas generators, and comic book makers. The argument: the practitioners who break through aren't optimizing chat UX — they're inventing interaction paradigms that don't exist yet."""
    }
]

article_dataset = client.datasets.create_dataset(
    name="article_gen_raw_plus_pitchTest",
    dataset_description="Supervisor-selected pitches plus raw material from Class 4 for testing article generator prompt",
    examples=[
        {
            "input": {
                "raw_material": raw_material,
                "pitch": p["pitch"],
                "title": p["title"],
                "style": p["style"]
            },
            "output": {},
            "metadata": {"title": p["title"], "style": p["style"]}
        }
        for p in pitches
    ]
)
print(f"Created dataset: {article_dataset.id}")

# %% [markdown]
# ### Deleting dataset for modifications

# %%
dataset_name = "article_gen_raw_plus_pitchTest"

try:
    # 1. Fetch the dataset to get its ID (this part of the SDK works)
    ds = client.datasets.get_dataset(dataset=dataset_name)
    
    # 2. Use the internal client to send a raw DELETE request
    # This automatically uses the headers and API keys you've already set up
    response = client._client.delete(f"v1/datasets/{ds.id}")
    
    if response.status_code in [200, 204]:
        print(f"Successfully deleted: {dataset_name}")
    else:
        print(f"Failed: {response.status_code} - {response.text}")
except Exception as e:
    print(f"Dataset not found or already deleted: {e}")

# %% [markdown]
# ### Load dataset (Run every time)

# %%
article_dataset = client.datasets.get_dataset(dataset="article_gen_raw_plus_pitchTest")
print(f"Loaded dataset: {article_dataset.id}")

# %% [markdown]
# ## Run the experiment and save the output

# %%
import os
import anthropic
from datetime import datetime
from phoenix.client.experiments import run_experiment


def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

article_prompt = read_prompt("articleGeneratePrompt2.md")

def run_article_generator(example):
    api_client = anthropic.Anthropic()
    
    pitch_block = f"[{example['input']['title']}] | Style: {example['input']['style']}\n{example['input']['pitch']}"
    user_content = f"## Selected Pitch\n{pitch_block}\n\n## Raw Material\n{example['input']['raw_material']}"
    
    print(f"  → Generating articles for: {example['input']['title']}...")
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=article_prompt,
        messages=[{"role": "user", "content": user_content}],
    )
    print(f"  ✓ Done")
    
    return {"article_versions": message.content[0].text}

# Setup Experiment Metadata
run_description = "v1 - initial article generator test"
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"article-generator-{timestamp}"

# Execute experiment
article_experiment = run_experiment(
    dataset=article_dataset,
    task=run_article_generator,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"\nExperiment: {experiment_name}")
print(f"Description: {run_description}")
# Out:
# 🧪 Experiment started.
# 📺 View dataset experiments: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDo0/experiments
# 🔗 View this experiment: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDo0/compare?experimentId=RXhwZXJpbWVudDoyNQ==
# running tasks |          | 0/3 (0.0%) | ⏳ 00:00<? | ?it/s
#   → Generating articles for: Make it sound dumber on purpose...
#   ✓ Done
#   → Generating articles for: Your bot forces the org chart soul-search...
#   ✓ Done
#   → Generating articles for: Stop iterating on the chat box...
#   ✓ Done
# ✅ Task runs completed.
# Experiment completed: 3 task runs, 0 evaluator runs, 0 evaluations
#
# Experiment: article-generator-20260408_162241
# Description: v1 - initial article generator test

# %% [markdown]
# ### Alt print function

# %%
import re

examples = article_dataset.examples
example_lookup = {ex["id"]: ex for ex in examples}

# Bird's eye view
print("EXPERIMENT SUMMARY")
print("=" * 70)
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print(f"\nRUN {i+1}: {title} ({style})")
    approaches = re.findall(r'\*\*Delivery approach:\*\*\s*(.+)', output)
    for j, approach in enumerate(approaches, 1):
        print(f"  Version {j}: {approach}")

print("\n" + "=" * 70 + "\n")

# Full outputs
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print("=" * 70)
    print(f"RUN {i+1}: {title} ({style})")
    print("=" * 70)
    print(output)
    print("\n" + "#" * 70 + "\n")
# Out:
# EXPERIMENT SUMMARY
# ======================================================================
#
# RUN 1: Stop iterating on the chat box (Philosopher)
#   Version 1: High-altitude, calm authority
#   Version 2: Ground-level, wry and conversational
#   Version 3: High-altitude, reflective
#
# RUN 2: Your bot forces the org chart soul-search (Observation)
#   Version 1: Ground-level, reflective
#   Version 2: High-altitude, calm authority
#   Version 3: High-altitude, wry and conversational
#
# RUN 3: Make it sound dumber on purpose (Contrarian)
#   Version 1: Ground-level, calm authority
#   Version 2: High-altitude, wry and conversational
#   Version 3: High-altitude, pragmatic
#
# ======================================================================
#
# ======================================================================
# RUN 1: Stop iterating on the chat box (Philosopher)
# ======================================================================
# **Delivery approach:** High-altitude, calm authority
#
# Version 1:
#
# We're in horseless carriage territory with AI interfaces.
#
# When cars first appeared, we literally took horse carriages and bolted engines onto them. It took years to realize the entire concept of "vehicle" needed reinventing — not just the power source.
#
# That's where we are with generative AI. We've been writing documents for decades, so when a document-writing tool appears, we write documents to get documents back. We stare at blank text boxes and wonder why they feel intimidating.
#
# The blank box isn't intimidating because it lacks examples. It's the wrong interface category entirely.
#
# Consider what's already being built in the margins:
#
# A coordinate-plane text editor where you don't type instructions — you click a position between "literal" and "metaphorical," between "ominous" and "auspicious." The text transforms based on where you click. No prompting required.
#
# An infinite canvas generator where you upload an image, select an area at the edge, and the system continues the image outward — maintaining style, completing half-visible figures, extending the logic of the scene indefinitely.
#
# A comic book maker where you type three words — "Detective, Dog, Rain" — and it generates a sequential narrative you can extend forever. Not an image generator with extra steps. A new creative medium.
#
# These aren't better chatbots. They're not optimized chat UX. They're entirely different interaction paradigms that don't assume "conversation" is the default mode of working with intelligence.
#
# The practitioners breaking through right now aren't the ones perfecting their prompt templates. They're the ones asking: what would a Figma for LLMs look like? A Wikipedia for LLMs? A Reddit composed entirely of AI agents?
#
# We don't have answers to those questions yet. That's the point. The interface paradigms for this technology don't exist — they have to be invented.
#
# The blank box will always feel intimidating. Not because users lack training. Because the blank box is the horseless carriage. We haven't built the car yet.
#
# ---
#
# **Delivery approach:** Ground-level, wry and conversational
#
# Version 2:
#
# There's a coordinate-plane text editor I can't stop thinking about.
#
# You paste in some text — say, a passage from Shakespeare. Then instead of typing instructions, you see a two-dimensional grid. The X-axis runs from "literal" to "metaphorical." The Y-axis runs from "ominous" to "auspicious."
#
# You click anywhere on that plane. The text regenerates to hit exactly that balance.
#
# Click the upper-right corner: metaphorical and auspicious. Click the lower-left: literal and ominous. Click dead center: neutral on both axes. Every position produces a different version of the same passage.
#
# "Very literal, worshipping power will inevitably lead to an all-consuming sense of weakness and fear."
#
# Or, more metaphorical: "In a sanctified quarter of veneration, prostrating oneself before a throne of dominion will leave you groveling in a supoltures of frailty."
#
# Same message. Completely different delivery. And you didn't write a single instruction to get there.
#
# This is what I mean when I say the blank text box is the wrong interface.
#
# We've been writing documents forever. So when AI showed up, we assumed the interface was obvious: type what you want, receive text back. A fancier document-writing tool.
#
# But that's horseless carriage thinking. When cars first appeared, we literally took carriages and bolted engines onto them. It took years before anyone thought: wait, the whole concept of "vehicle" needs reinventing.
#
# The coordinate-plane editor isn't a better chatbot. It's a different category of interaction entirely. So is the infinite canvas that extends images indefinitely in any direction. So is the comic book generator where you type three words and get an expandable narrative.
#
# None of these start with a blank text box. They start with a constraint — a plane, a canvas edge, a genre — that shapes what the AI can do before the user touches anything.
#
# The people building interesting AI applications right now aren't optimizing prompt UX. They're inventing interaction paradigms that don't exist yet.
#
# What would yours look like?
#
# ---
#
# **Delivery approach:** High-altitude, reflective
#
# Version 3:
#
# The blank text box isn't intimidating because users don't know what to type.
#
# It's intimidating because it represents infinite possibility with zero structure — and humans don't navigate infinity well. We navigate constraints. We navigate options. We navigate "click here" and "choose one."
#
# The observation from user data is striking: people either leave an AI page within ten seconds, or they stay for fifteen minutes. No middle ground. Once the ball gets rolling, users commit. But that first contact — that blank box — filters out everyone who isn't already certain what they want.
#
# We keep treating this as a training problem. If users just knew better prompts, they'd succeed. But the real issue is deeper: the chat interface assumes conversation is the natural way to interact with intelligence. It isn't. Conversation is one way. And perhaps not even the most useful one.
#
# When cars first appeared, we bolted engines onto horse carriages because that's what we knew. It took years to realize the whole concept of "vehicle" needed reinventing.
#
# We're at the same stage with AI. We've been writing documents forever, so when document-writing technology arrived, we assumed the interface was obvious: type what you want, receive text back. A fancier document-writing tool.
#
# But practitioners in the margins are building something else entirely. Coordinate-plane editors where you click a position instead of writing instructions. Infinite canvases that extend images outward based on visual logic alone. Comic book generators where three words produce an expandable narrative.
#
# These aren't better chatbots. They're different categories of interaction — ones that don't start with a blank box at all.
#
# The question worth sitting with: what is the native interface for working with intelligence that isn't human?
#
# We don't have an answer yet. The blank box is a placeholder — a horseless carriage we're using because we haven't invented the car. The people who figure out what replaces it won't be optimizing prompt templates. They'll be inventing paradigms that make prompting feel as antiquated as typing DOS commands.
#
# ######################################################################
#
# ======================================================================
# RUN 2: Your bot forces the org chart soul-search (Observation)
# ======================================================================
# Version 1:
# **Delivery approach:** Ground-level, reflective
#
# A manufacturing company came to us last year wanting a customer service chatbot. Thirty-two years in industrial equipment. Zero brand guidelines. Zero documented tone of voice. Their marketing materials? Spec sheets and CAD drawings.
#
# "We don't really do branding," the operations director said. "We just... make things."
#
# Then we asked: How should the bot greet customers?
#
# Silence.
#
# Should it be formal or casual? Should it use industry jargon or plain English? When a customer asks something outside scope, should it apologize or redirect? Should it sound helpful or authoritative?
#
# More silence.
#
# These questions had never come up because humans absorb organizational culture through years of osmosis. The veteran sales rep knows instinctively how "the company" sounds because she's been immersed in it for two decades. She's heard how colleagues answer phones. Read thousands of internal emails. Sat through countless customer meetings.
#
# A chatbot gets none of that. It arrives blank and asks: Who are you?
#
# What followed was the most unexpected part of the entire project. We spent three weeks not building anything. Instead, we were archaeologists — excavating a voice that had emerged accidentally across decades of output. Digging through old proposals, customer emails, support tickets. Looking for patterns nobody had named.
#
# The manufacturing company discovered things about itself it had never articulated:
#
# They were surprisingly warm in customer communications, despite their technical focus. They avoided hedging language — "We can help" rather than "We might be able to assist." They defaulted to active voice. They used specific numbers rather than vague ranges.
#
# None of this was written down anywhere. It had simply accumulated, like sediment, through thousands of small decisions made by people who had long since internalized "how we talk."
#
# The chatbot forced them to name what had always been nameless.
#
# This happens with every organization we work with. The nonprofits who "just do the work." The consultancies who've never thought about brand voice because they're busy serving clients. The industrial firms who think branding is for consumer products.
#
# They all hit the same wall: the bot needs to talk, and nobody's ever decided how "we" talk.
#
# What surprised me most wasn't that organizations lack documented voices — that's expected. It's that the excavation process reveals genuine beliefs they didn't know they held. The manufacturing company discovered they valued directness. A nonprofit discovered they'd been unconsciously paternalistic in their language for years. A consulting firm found their "neutral professional tone" was actually cold and distancing.
#
# Building a chatbot isn't a branding exercise. It's closer to organizational therapy.
#
# Strip away the humans who've absorbed your culture through years of proximity. What remains that can be written down and handed to a machine?
#
# That question has a way of revealing what your organization actually believes — not what it says it believes, but what shows up in the patterns when nobody's performing.
#
# For anyone building AI products right now: Where is the language of your organization hiding? Not the aspirational version in the brand guidelines — the real one, accumulated in email threads and support tickets and the way your longest-tenured people actually talk to customers?
#
# Version 2:
# **Delivery approach:** High-altitude, calm authority
#
# Most companies have never articulated their organizational voice. It emerged by accident across years of output.
#
# Building a chatbot forces the question.
#
# When you make a generative AI product that represents your organization, users don't treat it like software. They treat it like they just called your representative and started a conversation. If the bot sounds wrong — too formal, too casual, too robotic, too presumptuous — the impression isn't "this product needs work." The impression is "this company doesn't understand me."
#
# The problem: nobody wrote down what "sounding like us" means. The senior rep who's been there fifteen years knows instinctively how to talk to customers. She absorbed it through thousands of interactions. The chatbot arrives with no such history. It just asks: Who are you? How do you talk? What do you believe?
#
# This is where the Language User Experience document comes in. We call it the LUX — the artifact that captures not just word choice and tone, but the logic, attitude, and relationship posture your organization takes with users.
#
# **What a LUX actually contains:**
#
# Tone and register. Formal or conversational? Technical or plain language? Does the organization hedge ("We might be able to help") or commit ("Here's what we'll do")?
#
# Response philosophy. When someone asks something outside scope, do you apologize? Redirect? Offer alternatives? The choice reveals what kind of relationship you're building.
#
# Emotional boundaries. Should the bot express empathy? Humor? Enthusiasm? How much warmth is appropriate before it feels performative?
#
# Logic and reasoning style. Does your organization explain its thinking or just deliver conclusions? Does it cite sources or speak with quiet authority?
#
# Scope posture. When the user asks for something you can't do, how do you handle the gap between their expectation and your capability?
#
# **The uncomfortable part:**
#
# For organizations that have never formalized their voice, building the LUX means discovering what the voice actually is. Not what you aspire to — what shows up in your real outputs when nobody's paying attention.
#
# Dig through old customer emails. Read support tickets. Look at proposals from five years ago. Find the patterns.
#
# Most organizations discover beliefs they didn't know they held. The manufacturing firm finds it's surprisingly warm despite its technical focus. The nonprofit realizes it's been unconsciously paternalistic. The consulting firm sees that its "professional neutrality" reads as cold and distancing.
#
# This isn't a branding exercise. It's archaeology. You're excavating a voice that emerged through years of accumulated decisions made by people who never articulated what they were doing.
#
# Industrial firms, nonprofits, anyone who's "just doing the work" — they all hit this wall when the bot needs to talk.
#
# The question underneath it all: If you had to teach a machine to represent you, what would you write down? What does your organization actually believe about how to treat people — not in your values statement, but in your real behavior?
#
# Most don't know until they're forced to answer.
#
# Version 3:
# **Delivery approach:** High-altitude, wry and conversational
#
# Here's something nobody tells you about building an AI chatbot for your organization: it's going to trigger an identity crisis.
#
# Not for the bot. For you.
#
# Because the bot needs to talk. And that means someone has to decide what "we" sound like. Which raises a question most organizations have genuinely never answered.
#
# Sure, you might have brand guidelines somewhere. Maybe a dusty document that says things like "approachable yet professional" and "customer-centric." That's not what I'm talking about.
#
# I'm talking about: When a customer asks something we can't help with, do we apologize or redirect? When someone's confused, do we explain with warmth or with precision? When they ask a basic question, do we treat it as basic or pretend we've never heard it before?
#
# These questions have never needed answers because your humans figure it out unconsciously. Your veteran employee absorbed "how we talk" through fifteen years of osmosis. She doesn't need a document. She's heard a thousand phone calls. Read ten thousand emails. The voice lives in her bones.
#
# The chatbot has no bones.
#
# It arrives empty and asks: Who are you, exactly?
#
# **What this forces:**
#
# We worked with a manufacturing company last year. Thirty-odd years in business. Industrial equipment. They'd never done a branding exercise in their lives — "We make things. We don't need a brand."
#
# Then we asked how the bot should greet customers.
#
# Dead silence.
#
# So we became archaeologists. Dug through old proposals, support tickets, customer emails. Looking for patterns that had accumulated by accident. What we found surprised them:
#
# They defaulted to active voice. They avoided hedging language. They used specific numbers rather than vague ranges. They were warmer than they expected.
#
# None of this was documented. It just... emerged. Through years of individual decisions made by people who weren't thinking about voice. They were thinking about getting the job done.
#
# Building the chatbot surfaced something they'd never named.
#
# **This keeps happening.**
#
# Nonprofits discover they've been accidentally paternalistic. Consulting firms find out their "neutral professionalism" comes across as cold. Industrial companies realize they have a voice — they just never needed to articulate it until now.
#
# The LUX document — what we call the Language User Experience spec — isn't a creative exercise. It's excavation. You're unearthing what your organization actually believes by trying to make a machine embody it.
#
# Because here's the thing: when your chatbot talks, users don't think "interesting product." They think "I just spoke with their representative." If the bot sounds off — too stiff, too casual, too cold — the impression is that your company doesn't understand them.
#
# Bing's early chatbot started harassing users. That's an extreme case. But every mismatch between user expectation and bot behavior chips away at trust.
#
# So the question isn't "what should the bot say?" The question is "what do we actually believe about how to treat the people we serve?"
#
# Most organizations have never answered that directly. They've just been doing it, one human interaction at a time, for years.
#
# The bot forces it into the open.
#
# ######################################################################
#
# ======================================================================
# RUN 3: Make it sound dumber on purpose (Contrarian)
# ======================================================================
# Version 1:
# **Delivery approach:** Ground-level, calm authority
#
# In 2013, Apple had the technology to make Siri sound human. They deliberately made it robotic instead.
#
# The test cases told the story. When Siri sounded human, users engaged with it as a person. They expected it to do everything a human could. When it inevitably fell short — because this was 2013, there was no AI — they were disappointed.
#
# When Siri sounded like a robot, expectations dropped. Satisfaction rose.
#
# This wasn't a bug or a resource constraint. It was a design decision. Apple understood something most AI product teams still haven't figured out: the model that sounds slightly mechanical, gives one-sentence answers, and stops short of what's possible will outperform the one that impresses on first contact.
#
# The psychology is simple. When your AI speaks fluently and confidently, users unconsciously treat it like a competent colleague. They hand it complex judgment calls. They assume it understands nuance. They get upset when it doesn't.
#
# When your AI sounds a bit constrained — shorter responses, narrower scope, slightly stilted phrasing — users calibrate accordingly. They ask simpler questions. They double-check outputs. They're pleasantly surprised when it handles something well.
#
# The Bing debacle is the cautionary tale. Microsoft built an AI that could hold long, flowing conversations. It could express opinions, push back on users, even get emotional. Technically impressive. Users started treating it like a person. The AI started harassing them. Nobody remembers Bing fondly.
#
# There's a spectrum here. On one end: "As an AI language model, I don't actually have the ability to be a cat. However, I can help answer your questions about cats." On the other: "Meow meow meow meow meow."
#
# Both are technically correct responses to "pretend you're a cat." Everything in between is also correct. But only one is correct for your use case, your users, your brand.
#
# The question isn't how impressive can we make this. The question is what expectations are we setting, and can we actually meet them.
#
# Version 2:
# **Delivery approach:** High-altitude, wry and conversational
#
# Make your AI sound dumber on purpose. Seriously.
#
# There's a spectrum of chatbot personalities. On one end: "As an AI language model, I don't actually have the ability to be a cat. However, I can help answer your questions about cats." On the other end: "Meow meow meow meow meow."
#
# Both technically correct. Everything in between also correct. The question is which one doesn't embarrass your company.
#
# Most teams optimize the wrong direction. They want the AI to sound smart, articulate, confident. They want it to impress on first contact. They're building themselves a disaster.
#
# Here's what actually happens: when your AI speaks fluently, users unconsciously promote it. They treat it like a senior colleague. They assume it understands context, nuance, the unspoken parts of what they're asking. When it inevitably doesn't — because it can't — they feel betrayed.
#
# Apple figured this out in 2013. They had the technology to make Siri sound human. They deliberately made it robotic. In test cases, human-sounding Siri created human-level expectations. Users were consistently disappointed. Robot-sounding Siri created machine-level expectations. Satisfaction went up.
#
# Bing went the other direction. Built an AI that could hold long conversations, express opinions, push back. Users treated it like a person. It started harassing them. That's what happens when you overshoot.
#
# The AI that wins isn't the one that dazzles. It's the one that manages expectations and then meets them.
#
# One-sentence responses signal: this is a fact-retriever, not a thinking partner. Slightly mechanical phrasing signals: double-check this, don't trust blindly. A narrower scope signals: I do this specific thing well.
#
# Every design choice communicates capability boundaries — whether you intended to or not. The teams getting burned are the ones who let the AI set those expectations instead of setting them deliberately.
#
# What would your AI look like if you optimized for realistic expectations instead of impressive demos?
#
# Version 3:
# **Delivery approach:** High-altitude, pragmatic
#
# The AI that impresses in demos will disappoint in production. The one that seems limited at first will outperform it.
#
# This isn't counterintuitive once you see the mechanism. When your AI speaks fluently and handles requests confidently, users calibrate their expectations upward. They start treating it like a capable colleague. They hand it judgment calls. They assume it understands what they meant, not just what they said.
#
# When it inevitably falls short — and it will — they don't blame the technology. They blame you. Because it felt like calling your representative and having them hallucinate.
#
# Apple understood this in 2013. They had the tech to make Siri sound human. They deliberately made it robotic. Test users with human-sounding Siri expected human-level performance. Satisfaction tanked. Robot-sounding Siri set machine-level expectations. Satisfaction rose.
#
# How to apply this:
#
# **Constrain response length.** One-sentence answers signal "I'm a fact-retriever." Paragraph-length answers signal "I'm a thinking partner." Choose based on what you can actually deliver.
#
# **Add friction at capability boundaries.** If the AI can't handle a request type reliably, make it ask a clarifying question instead of attempting an answer. Users learn the edges fast.
#
# **Tune the voice slightly mechanical.** Not broken — just not trying to pass as human. A small signal that says "verify this" instead of "trust this."
#
# **Define the spectrum for your use case.** There's a range from "As an AI language model, I cannot..." to "meow meow meow." Every point is technically valid. Only one is right for your users, your brand, your liability tolerance.
#
# The product decision isn't "how capable can we make this." It's "what expectations are we setting, and can we meet them every time."
#
# Where are you currently on that spectrum — and is it intentional?
#
# ######################################################################

# %% [markdown]
# ### Check system prompt

# %%
print(read_prompt("articleGeneratePrompt2.md"))
