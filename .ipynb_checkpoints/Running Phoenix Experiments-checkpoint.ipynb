# %% [markdown]
# ## Set up the Phoenix connection and establish a test dataset
# ### Connects to Phoenix

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["PHOENIX_CLIENT_HEADERS"] = f"api_key={os.getenv('PHOENIX_API_KEY')}"
os.environ["PHOENIX_COLLECTOR_ENDPOINT"] = "https://app.phoenix.arize.com/s/linkedInArticleGen"

from phoenix.client import Client
client = Client()
print("Connected to Phoenix")

# %% [markdown]
# ### Initiate new dataset (only needs running once when starting new dataset)
# Read the transcript from Class 4 from a local file, then creates a dataset in Phoenix with that transcript stored as a re-usable test set.
#
# Later experiments will feed this test case for later tests for objective comparison of outputs.

# %%
## Read the dataset
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

## Creates a dataset with the given name and stored experiment
dataset = client.datasets.create_dataset(
    name="initial_test_from_Class_4",
    dataset_description="Lecture transcripts and articles from class 4 for testing initial batch of prompts",
    examples=[
        {
            "input": {"raw_material": raw_material},
            "output": {},
            "metadata": {"source": "class 4 transcript"}
        }
    ]
)
print(f"Created dataset: {dataset.id}")

# %% [markdown]
# ### Run old dataset

# %%
# Load existing dataset (already created in Phoenix)
dataset = client.datasets.get_dataset(dataset="initial_test_from_Class_4")
print(f"Loaded dataset: {dataset.id}")

# %% [markdown]
# # Run the experiment for angleProposalPrompt1.md
# ### Load the experiment and store the output

# %%
# Load the Phoenix experiment runner
from phoenix.client.experiments import run_experiment
from datetime import datetime
import anthropic

# Helper to read prompt files from the prompts/ folder
def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

# Load current angle proposal prompt (re-reads from file each time so edits are picked up)
angle_prompt = read_prompt("angleProposalPrompt1.md")

# Define the task — Phoenix runs this against each example in the dataset
def angle_proposal_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

# Auto-generate unique experiment name from timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-{timestamp}"

# Run the experiment
latest_experiment = run_experiment(
    dataset=dataset,
    task=angle_proposal_task,
    experiment_name=experiment_name,
    experiment_description="Auto-run",
    timeout=120
)

print(f"Experiment: {experiment_name}")

# %% [markdown]
# ## Export the experiment in a legible format

# %% [markdown]
# ### Export the prompt sys message

# %%
# See what was sent to the API as the system prompt
print("=" * 60)
print("SYSTEM PROMPT:")
print("=" * 60)
print(angle_prompt)

# %% [markdown]
# ### For exporting the user message

# %%
# See the input that was sent as the user message
print("=" * 60)
print("USER MESSAGE (first 500 chars):")
print("=" * 60)
print(raw_material[:500])

# %% [markdown]
# ### For exporting a single experiment output

# %%
# Pull the latest experiment results in a readable format
for run in latest_experiment["task_runs"]:
    print("=" * 60)
    print("OUTPUT:")
    print("=" * 60)
    print(run["output"])
    print("\n\n")

# %% [markdown]
# # Run the experiment up to supervisorPrompt1.5 04.04.26
# ## Run the pipeline up to supervisorPrompt

# %%
import time
import re

def extract_final_pitches(output):
    """Extract only the Final Pitches section, stripping all reasoning."""
    marker = "## Final Pitches"
    idx = output.find(marker)
    if idx != -1:
        return output[idx + len(marker):].strip()
    match = re.search(r"##\s*Final\s*Pitches", output, re.IGNORECASE)
    if match:
        return output[match.end():].strip()
    return output.strip()

def full_angle_pipeline(input):
    api_client = anthropic.Anthropic()
    
    # Load prompts
    angle_prompt = read_prompt("angleProposalPrompt1.md")
    supervisor_prompt = read_prompt("supervisorPrompt1.md")
    
    # Run angle proposal 3 times, extract only final pitches
    extracted_pitches = []
    for i in range(1, 4):
        if i > 1:
            time.sleep(10)
        message = api_client.messages.create(
            model="claude-opus-4-5-20251101",
            max_tokens=16000,
            system=angle_prompt,
            messages=[{"role": "user", "content": input["raw_material"]}],
        )
        pitches = extract_final_pitches(message.content[0].text)
        extracted_pitches.append(pitches)
    
    # Combine extracted pitches into labeled block
    combined = ""
    for i, pitches in enumerate(extracted_pitches, 1):
        combined += f"## Batch {i}\n\n{pitches}\n\n"
    
    # Run supervisor on combined pitches
    supervisor_message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=supervisor_prompt,
        messages=[{"role": "user", "content": combined}],
    )
    
    # Return both what supervisor received and what it chose
    return {
        "supervisor_input": combined,
        "supervisor_output": supervisor_message.content[0].text
    }

# Run the experiment
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"full-pipeline-upToSupervisor-{timestamp}"

latest_experiment = run_experiment(
    dataset=dataset,
    task=full_angle_pipeline,
    experiment_name=experiment_name,
    experiment_description="Full pipeline up to supervisor: 3 batches + supervisor",
    timeout=1000  # longer timeout for 4 API calls
)

print(f"Experiment: {experiment_name}")

# %%
for run in latest_experiment["task_runs"]:
    output = run["output"]
    
    print("=" * 60)
    print("WHAT THE SUPERVISOR RECEIVED:")
    print("=" * 60)
    print(output["supervisor_input"])
    
    print("\n\n")
    
    print("=" * 60)
    print("WHAT THE SUPERVISOR CHOSE:")
    print("=" * 60)
    print(output["supervisor_output"])
# Out:
# ============================================================
# WHAT THE SUPERVISOR RECEIVED:
# ============================================================
# ## Batch 1
#
# [1] **Ten seconds or fifteen minutes** (Observation): Users either bounce from your AI interface immediately or they stay for an extended session — there's almost no middle ground. The blank chat box triggers the same cognitive paralysis as staring at an empty document. The teams that get engagement are the ones who replace the open sandbox with guided entry points: buttons, questionnaires, anything that lets users click before they have to think.
#
# [2] **Your chatbot is your sales rep** (Contrarian): When your AI starts talking, users don't judge it like software — they judge it like they just called your company and got a person. If it hallucinates or gets the tone wrong, the psychological damage is the same as an untrained rep fumbling a call. Most companies wouldn't let someone answer phones without training on voice and boundaries, but they're shipping chatbots without any of that discipline.
#
# [3] **You ship features you never built** (Framework): An AI that can answer general questions will also answer questions you never intended it to answer. Your road trip planner can tell users where to buy marijuana. Your philanthropy advisor can recommend specific charities you've never vetted. The capability surface of an AI tool is much larger than what you explicitly designed — which means you're implicitly approving features nobody ever reviewed. The work isn't just defining what it should do, but mapping the entire spectrum of what it could do and deciding where each capability falls: hard no, redirect, ask first, or let through.
#
# ## Batch 2
#
# [1] **Your AI policy needs soft yeses** (Contrarian): When an employee gets fired for putting sensitive data into a free AI tool, the headline is "employee violated policy." But the real failure is the organization that gave them thirty no's and zero legitimate alternatives. The material here shows what happens when people only hear restrictions: they either go underground or disengage entirely. The fix isn't looser rules — it's providing clear, safe paths alongside the guardrails. A policy built entirely on prohibition is a policy that teaches people to stop asking for permission.
#
# [2] **Siri's best design decision was sounding like a robot** (Observation): In 2013, Apple had the technology to make Siri sound human. They deliberately chose not to. When testers heard a human-sounding voice, they expected human-level capability — and satisfaction plummeted when the system couldn't deliver. Making Siri sound robotic lowered expectations and raised satisfaction. Meanwhile, today's AI products race toward conversational warmth while users grow frustrated that the warm voice can't actually do what a warm human could. The 2013 insight still applies: capability presentation creates expectation debt you have to pay back.
#
# [3] **AI outputs aren't product features, they're phone calls to your company** (Philosopher): When traditional software breaks, users think "the product has a bug." When AI outputs something wrong, users think "your company just said something crazy to me." The shift from deterministic to generative flips the stakes: a chatbot that hallucinates isn't a broken feature — it's a representative who went off-script on a customer call. This is why the "voice" work that feels like polish is actually the core product decision. Every edge case is a brand moment. Every response carries your name in a way that a button never did.
#
# ## Batch 3
#
# [1] **The blank box is a lie** (Observation): Every AI product starts as a text input. Users see infinite possibility, which is exactly the problem — they don't know what to ask, so they leave. The best AI products aren't chatbots at all. They're questionnaires with a generative engine underneath, shaping user expectations before the user even knows AI is involved.
#
# [2] **Your chatbot called me a name** (Philosopher): Users don't experience your AI as software. They experience it as a conversation with someone who represents your company. When the bot hallucinates or gets weird, it's not a bug report — it's reputational damage, felt the way a rude phone call would be. Most companies have never articulated their voice because they've never had to. Now they do, or they'll discover it the hard way.
#
# [3] **The queries that scare you are the product roadmap** (Contrarian): When users start asking your roadtrip planner for marijuana dispensaries, the instinct is to block them. But these off-label queries are the clearest signal you'll ever get about what people actually want from you — clearer than any survey, any user interview. The requests that make you uncomfortable are the product telling you what to build next.
#
#
#
#
#
# ============================================================
# WHAT THE SUPERVISOR CHOSE:
# ============================================================
# ## Analysis
#
# ### Clustering by Argument
#
# **Cluster A: The blank input box causes paralysis/abandonment**
# - Batch 1, Pitch 1: "Ten seconds or fifteen minutes"
# - Batch 3, Pitch 1: "The blank box is a lie"
#
# Both argue that open-ended AI interfaces paralyze users. Batch 1's delivery is more specific ("ten seconds or fifteen minutes" is a memorable concrete observation; "click before they have to think" is vivid). Batch 3 is more compressed but less distinctive — "infinite possibility is the problem" is a weaker version of the same insight.
#
# **Winner in cluster: Batch 1, Pitch 1**
#
# **Cluster B: AI outputs are judged like human representatives, not software**
# - Batch 1, Pitch 2: "Your chatbot is your sales rep"
# - Batch 2, Pitch 3: "AI outputs aren't product features, they're phone calls to your company"
# - Batch 3, Pitch 2: "Your chatbot called me a name"
#
# All three argue the same core insight: AI errors feel like interpersonal failures, not technical bugs. Batch 2, Pitch 3 has the strongest philosophical framing ("a button never carried your name the way a response does"), but Batch 1, Pitch 2 has the sharpest hook ("Most companies wouldn't let someone answer phones without training, but they're shipping chatbots without any of that discipline"). Batch 3, Pitch 2 is the weakest — it's making the same point but with less punch.
#
# **Winner in cluster: Batch 1, Pitch 2** (the "untrained rep fumbling a call" comparison is more visceral than the philosophical version)
#
# **Cluster C: AI capability surfaces are larger than what you designed**
# - Batch 1, Pitch 3: "You ship features you never built"
# - Batch 3, Pitch 3: "The queries that scare you are the product roadmap"
#
# These are related but genuinely distinct. Batch 1, Pitch 3 is about governance — the marijuana/charity examples show unreviewed capabilities leaking through. Batch 3, Pitch 3 flips the same raw material into a different argument: those queries aren't threats, they're market signals. The contrarian reframe ("the product telling you what to build next") is the fresher take — most readers will nod along with "you should audit capabilities" but will actually stop and think at "those scary queries are your roadmap."
#
# **Winner in cluster: Batch 3, Pitch 3** (genuinely distinct contrarian angle with a memorable hook)
#
# **Cluster D: Expectation-setting through AI presentation**
# - Batch 2, Pitch 2: "Siri's best design decision was sounding like a robot"
#
# This is an outlier — no other batch touched the Siri anecdote or the "capability presentation creates expectation debt" framing. The concrete historical example (Apple deliberately downgraded Siri's voice) makes the abstract principle tangible. This is strong and unique.
#
# **Cluster E: Prohibition-only policies fail**
# - Batch 2, Pitch 1: "Your AI policy needs soft yeses"
#
# Also an outlier. The "thirty no's and zero alternatives" framing is memorable, and the insight (restriction-only policies teach people to stop asking) is practical. However, this feels slightly more like standard organizational advice than the other outliers.
#
# ### Evaluating for Variety
#
# If I select from Clusters A, B, and C, I get:
# - User interface/psychology
# - Brand/reputation stakes
# - Product strategy
#
# That's reasonable variety. But the Siri pitch (Cluster D) offers something none of the others do: a concrete historical case study with a counterintuitive lesson. It's also operating at a different level — about expectation design rather than crisis management.
#
# The strongest three would be:
# 1. Batch 1, Pitch 1 (blank box/ten seconds)
# 2. Batch 3, Pitch 3 (scary queries as roadmap)
# 3. Batch 2, Pitch 2 (Siri's robot voice)
#
# This combination covers: UX psychology, product strategy, and expectation design — genuinely different directions. The "chatbot as sales rep" pitch is strong but overlaps more with the brand-danger territory that's already partially covered by the Siri piece (both are about how AI presentation affects user perception).
#
# ---
#
# ## Selected Pitches
#
# [1] **Ten seconds or fifteen minutes** | Style: Observation
# Users either bounce from your AI interface immediately or they stay for an extended session — there's almost no middle ground. The blank chat box triggers the same cognitive paralysis as staring at an empty document. The teams that get engagement are the ones who replace the open sandbox with guided entry points: buttons, questionnaires, anything that lets users click before they have to think.
#
# [2] **The queries that scare you are the product roadmap** | Style: Contrarian
# When users start asking your roadtrip planner for marijuana dispensaries, the instinct is to block them. But these off-label queries are the clearest signal you'll ever get about what people actually want from you — clearer than any survey, any user interview. The requests that make you uncomfortable are the product telling you what to build next.
#
# [3] **Siri's best design decision was sounding like a robot** | Style: Observation
# In 2013, Apple had the technology to make Siri sound human. They deliberately chose not to. When testers heard a human-sounding voice, they expected human-level capability — and satisfaction plummeted when the system couldn't deliver. Making Siri sound robotic lowered expectations and raised satisfaction. Meanwhile, today's AI products race toward conversational warmth while users grow frustrated that the warm voice can't actually do what a warm human could. The 2013 insight still applies: capability presentation creates expectation debt you have to pay back.
