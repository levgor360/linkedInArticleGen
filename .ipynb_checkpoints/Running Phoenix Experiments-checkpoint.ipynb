# %% [markdown]
# ## Set up the Phoenix connection and establish a test dataset
# ### Connects to Phoenix

# %%
import os
os.environ.pop("ALL_PROXY", None)
os.environ.pop("all_proxy", None)
from dotenv import load_dotenv
load_dotenv()
os.environ["PHOENIX_CLIENT_HEADERS"] = f"api_key={os.getenv('PHOENIX_API_KEY')}"
os.environ["PHOENIX_COLLECTOR_ENDPOINT"] = "https://app.phoenix.arize.com/s/linkedInArticleGen"

from phoenix.otel import register
from opentelemetry.instrumentation.anthropic import AnthropicInstrumentor
register(project_name="linkedInArticleGen")
AnthropicInstrumentor().instrument()

from phoenix.client import Client
client = Client()
print("Connected to Phoenix")
# Out:
# /home/mouse/artGenT430/venv/lib/python3.12/site-packages/phoenix/otel/otel.py:433: UserWarning: Could not infer collector endpoint protocol, defaulting to HTTP.
#   warnings.warn("Could not infer collector endpoint protocol, defaulting to HTTP.")
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: linkedInArticleGen
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/s/linkedInArticleGen/v1/traces
# |  Transport: HTTP + protobuf
# |  Transport Headers: {'api_key': '****', 'authorization': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  ⚠️ WARNING: It is strongly advised to use a BatchSpanProcessor in production environments.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.
#
# Connected to Phoenix

# %%
from opentelemetry import trace
tracer = trace.get_tracer(__name__)
print(trace.get_tracer_provider())
# Out:
# <phoenix.otel.otel.TracerProvider object at 0x7bca8e1f7740>

# %% [markdown]
# ### Initiate new dataset (only needs running once when starting new dataset)
# Read the transcript from Class 4 from a local file, then creates a dataset in Phoenix with that transcript stored as a re-usable test set.
#
# Later experiments will feed this test case for later tests for objective comparison of outputs.
#
# *One time*

# %%
## Read the dataset
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

## Creates a dataset with the given name and stored experiment
dataset = client.datasets.create_dataset(
    name="initial_test_from_Class_4",
    dataset_description="Lecture transcripts and articles from class 4 for testing initial batch of prompts",
    examples=[
        {
            "input": {"raw_material": raw_material},
            "output": {},
            "metadata": {"source": "class 4 transcript"}
        }
    ]
)
print(f"Created dataset: {dataset.id}")

# %% [markdown]
# ### Run old dataset

# %%
# Load existing dataset (already created in Phoenix)
dataset = client.datasets.get_dataset(dataset="initial_test_from_Class_4")
print(f"Loaded dataset: {dataset.id}")
# Out:
# Loaded dataset: RGF0YXNldDoy

# %% [markdown]
# # Run the experiment for angleProposalPrompt1.md
# ## Run the experiment and store the output

# %%
# Load the Phoenix experiment runner
from phoenix.client.experiments import run_experiment
from datetime import datetime
import anthropic

# Helper to read prompt files from the prompts/ folder
def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

# Load current angle proposal prompt (re-reads from file each time so edits are picked up)
angle_prompt = read_prompt("angleProposalPrompt1.md")

# Define the task — Phoenix runs this against each example in the dataset
def angle_proposal_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

# Auto-generate unique experiment name from timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-{timestamp}"

# Run the experiment
latest_experiment = run_experiment(
    dataset=dataset,
    task=angle_proposal_task,
    experiment_name=experiment_name,
    experiment_description="Auto-run",
    timeout=120
)

print(f"Experiment: {experiment_name}")

# %% [markdown]
# ## Export the experiment in a legible format

# %% [markdown]
# ### Export the prompt sys message

# %%
# See what was sent to the API as the system prompt
print("=" * 60)
print("SYSTEM PROMPT:")
print("=" * 60)
print(angle_prompt)

# %% [markdown]
# ### For exporting the user message

# %%
# See the input that was sent as the user message
print("=" * 60)
print("USER MESSAGE (first 500 chars):")
print("=" * 60)
print(raw_material[:500])

# %% [markdown]
# ### For exporting a single experiment output

# %%
# Pull the latest experiment results in a readable format
for run in latest_experiment["task_runs"]:
    print("=" * 60)
    print("OUTPUT:")
    print("=" * 60)
    print(run["output"])
    print("\n\n")

# %% [markdown]
# # Run the experiment up to supervisorPrompt1.5
# ## Run the pipeline up to supervisorPrompt

# %%
import time
import re
from datetime import datetime
from phoenix.client.experiments import run_experiment
import anthropic

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

def extract_final_pitches(output):
    """Extract only the Final Pitches section, stripping all reasoning."""
    marker = "## Final Pitches"
    idx = output.find(marker)
    if idx != -1:
        return output[idx + len(marker):].strip()
    match = re.search(r"##\s*Final\s*Pitches", output, re.IGNORECASE)
    if match:
        return output[match.end():].strip()
    return output.strip()

def full_angle_pipeline(input):
    api_client = anthropic.Anthropic()
    
    # Load prompts
    angle_prompt = read_prompt("angleProposalPrompt1.md")
    supervisor_prompt = read_prompt("supervisorPrompt1.5.md")
    
    # Run angle proposal 3 times, extract only final pitches
    extracted_pitches = []
    for i in range(1, 4):
        print(f"  → Angle proposal {i}/3...")
        if i > 1:
            time.sleep(10)
        message = api_client.messages.create(
            model="claude-opus-4-5-20251101",
            max_tokens=16000,
            system=angle_prompt,
            messages=[{"role": "user", "content": input["raw_material"]}],
        )
        pitches = extract_final_pitches(message.content[0].text)
        extracted_pitches.append(pitches)
        print(f"  ✓ Batch {i} complete")
    
    # Combine extracted pitches into labeled block
    combined = ""
    for i, pitches in enumerate(extracted_pitches, 1):
        combined += f"## Batch {i}\n\n{pitches}\n\n"
    
    # Run supervisor on combined pitches
    print("  → Running supervisor...")
    supervisor_message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=supervisor_prompt,
        messages=[{"role": "user", "content": combined}],
    )
    print("  ✓ Pipeline complete")
    
    return {
        "supervisor_input": combined,
        "supervisor_output": supervisor_message.content[0].text
    }

# ---- CHANGE THIS EACH RUN WHEN NEW DATASET IS EMPLOYED----
run_description = "v1.5 - modded cohesion reviewer 04.06.26"
# --------------------------------

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"full-pipeline-upToSupervisor-{timestamp}"

latest_experiment = run_experiment(
    dataset=dataset,
    task=full_angle_pipeline,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"Experiment: {experiment_name}")
print(f"Description: {run_description}")
# Out:
# 🧪 Experiment started.
# 📺 View dataset experiments: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDoy/experiments
# 🔗 View this experiment: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDoy/compare?experimentId=RXhwZXJpbWVudDoyOA==
# running tasks |          | 0/1 (0.0%) | ⏳ 00:00<? | ?it/s
#   → Angle proposal 1/3...
#   ✓ Batch 1 complete
#   → Angle proposal 2/3...
#   ✓ Batch 2 complete
#   → Angle proposal 3/3...
#   ✓ Batch 3 complete
#   → Running supervisor...
#   ✓ Pipeline complete
# ✅ Task runs completed.
# Experiment completed: 1 task runs, 0 evaluator runs, 0 evaluations
# Experiment: full-pipeline-upToSupervisor-20260409_172420
# Description: v1.5 - modded cohesion reviewer 04.06.26

# %% [markdown]
# ### Print results for the run above

# %%
for run in latest_experiment["task_runs"]:
    output = run["output"]
    
    # print("=" * 60)
    # print("WHAT THE SUPERVISOR RECEIVED:")
    # print("=" * 60)
    # print(output["supervisor_input"])
    
    # print("\n\n")
    
    print("=" * 60)
    print("WHAT THE SUPERVISOR CHOSE:")
    print("=" * 60)
    print(output["supervisor_output"])
# Out:
# ============================================================
# WHAT THE SUPERVISOR CHOSE:
# ============================================================
# ## Analysis
#
# ### Clustering by Argument
#
# **Cluster A: The blank chat interface is the adoption killer**
# - Batch 1, Pitch 1: "Your AI fails at the text box"
# - Batch 2, Pitch 1: "The ten-second cliff in AI adoption"
# - Batch 3, Pitch 1: "Your chatbot is a dead end"
#
# All three argue that the chat interface itself — not the model, not the prompts — is what causes adoption failure. They all point to the same insight: users either engage deeply or abandon immediately, and the blank text box is the filter.
#
# **Cluster B: Your AI is an unvetted representative of your organization**
# - Batch 1, Pitch 3: "Your AI already has a personality"
# - Batch 2, Pitch 2: "Your chatbot is an unvetted spokesperson"
# - Batch 3, Pitch 2: "Your AI is your receptionist"
#
# All three use the Apple/Siri 2013 example. All three argue that AI is perceived as a person speaking for your company, not as software. The core claim is identical: you're making a staffing decision, not a technology decision, whether you realize it or not.
#
# **Cluster C: AI testing requires defining the gray zone**
# - Batch 1, Pitch 2: "The AI roadmap is subtraction"
# - Batch 2, Pitch 3: "AI testing is psychology, not quality assurance"
#
# Both argue that the work is mapping ambiguous territory between clear yes and clear no. Batch 1 frames it as roadmap work (subtraction, edge cases). Batch 2 frames it as testing work (psychology, not QA). Same underlying insight: you need to define the spectrum before users find the edges.
#
# **Outlier:**
# - Batch 3, Pitch 3: "Soft yeses beat hard no's"
#
# This is genuinely distinct. It's about AI governance/policy design, not product design or testing. The insight — that explicit approvals work better than lists of prohibitions — doesn't appear anywhere else. Worth evaluating on its own.
#
# ---
#
# ### Evaluating Deliveries Within Clusters
#
# **Cluster A (Chat interface problem):**
#
# Batch 1 has a weak delivery. "User data shows the first 10 seconds determine everything" is asserted but not made vivid. "Most teams spend months on prompts and hours on the interface" is a nice inversion but feels like a slogan.
#
# Batch 2 has the strongest specific detail: "users either bail within seconds of seeing a chatbot or stay for 15+ minutes — there's almost no middle ground." This is concrete data that creates the bimodal picture. The line "The blank text box isn't a neutral starting point; it's a filter that selects only for people who already know what to do with AI" is quotable — it reframes the interface as selection mechanism, not design choice. "The product is the ramp, not the capability" is punchy but slightly disconnected.
#
# Batch 3 has the best framing device: "horseless carriage territory." This earns its place — it's not just a metaphor, it's a diagnosis of where we are historically. "A blank box that demands users already know what to ask" is clear. "The teams winning aren't building better chatbots. They're abandoning the format entirely" is a strong closer.
#
# **Best lines to harvest from Cluster A:**
# - "users either bail within seconds of seeing a chatbot or stay for 15+ minutes — there's almost no middle ground" (B2)
# - "The blank text box isn't a neutral starting point; it's a filter that selects only for people who already know what to do with AI" (B2)
# - "We're in horseless carriage territory with AI interfaces" (B3)
# - "The teams winning aren't building better chatbots. They're abandoning the format entirely" (B3)
#
# **Cluster B (AI as spokesperson):**
#
# Batch 1 opens philosophically but meanders. "They understood that voice shapes expectation, and expectation shapes satisfaction" — true but abstract. "The question isn't whether to design your AI's personality — it's whether to do it on purpose" is a decent closer but the pitch never earns the landing because it doesn't establish the stakes.
#
# Batch 2 has the strongest single image: "If it hallucinates, they don't think 'bad product'; they think 'your employee lost their mind on the phone with me.'" This is vivid and earns its place. "Most companies are shipping human-sounding AI without realizing they've hired a spokesperson they've never interviewed" — strong closer, concrete metaphor.
#
# Batch 3 is cleaner but less punchy. "They feel like they called your company and your representative started hallucinating at them" is close to B2's version but slightly weaker. "Deploying AI isn't a technical decision. It's a decision about who speaks for your organization and what happens when they're wrong" — solid but more abstract than B2's interview metaphor.
#
# **Best lines to harvest from Cluster B:**
# - "When your generative AI product misbehaves, users don't think 'this software has a bug.' They feel like they called your company and your representative started hallucinating at them." (B3, slightly cleaner setup)
# - "If it hallucinates, they don't think 'bad product'; they think 'your employee lost their mind on the phone with me.'" (B2, punchier image — use this one)
# - "Apple made Siri sound robotic in 2013 even though they had the tech to make it sound human — they were managing expectations through voice design" (B3, cleanest delivery of the Apple example)
# - "Most companies are shipping human-sounding AI without realizing they've hired a spokesperson they've never interviewed" (B2)
#
# **Cluster C (Defining the gray zone):**
#
# Batch 1 leads with emergent use cases ("marijuana dispensaries, political commentary") — these are specific and interesting, but they're examples without a clear argument structure. "The work isn't adding features. It's mapping the space between 'definitely yes' and 'definitely no'" is the thesis, but it comes after the examples, which makes the pitch feel backward.
#
# Batch 2 has the sharper framing: "Traditional QA asks whether software does what developers intended. AI testing asks whether the genie granted the wish the user actually wanted." The genie metaphor is vivid and earns its place. "A road trip planner that suggests rocky beaches for a 'beach vacation' is technically correct and psychologically wrong" — concrete example that makes the abstract tangible. "Your legal team is now part of product testing" — strong, unexpected implication.
#
# **Best lines to harvest from Cluster C:**
# - "Traditional QA asks whether software does what developers intended. AI testing asks whether the genie granted the wish the user actually wanted." (B2)
# - "A road trip planner that suggests rocky beaches for a 'beach vacation' is technically correct and psychologically wrong." (B2)
# - "Your legal team is now part of product testing." (B2)
# - "marijuana dispensaries, political commentary, capabilities that emerge from tools you didn't build for them" (B1 — good texture, could supplement)
#
# **Outlier (Soft yeses):**
#
# The insight is distinct and useful: approval lists work better than prohibition lists. "When people hear 'no' repeatedly, they either stop trying entirely or go underground with shadow tools" — this is specific and rings true. "The policy question isn't 'what should we forbid?' It's 'what should we make obviously okay?'" — solid reframe.
#
# The delivery is decent but not as vivid as the best pitches in the clusters. It's making a real argument, but it lacks a concrete image or memorable line. However, it's the only pitch addressing organizational governance rather than product design, which makes it valuable for variety.
#
# ---
#
# ### Composing Strongest Deliveries
#
# **Cluster A composed pitch:**
# We're in horseless carriage territory with AI interfaces. Everyone debates which chatbot is better while ignoring that the chat format itself is the problem. User data tells the story: people either bail within seconds of seeing a chatbot or stay for 15+ minutes — there's almost no middle ground. The blank text box isn't a neutral starting point; it's a filter that selects only for people who already know what to do with AI. The teams winning aren't building better chatbots. They're abandoning the format entirely.
#
# *Review: Thematically tight — every sentence drives toward "the interface is the problem, not the model." Reads naturally, flows from historical diagnosis to data to reframe to implication.*
#
# **Cluster B composed pitch:**
# When your AI misbehaves, users don't think "this software has a bug." They feel like they called your company and a representative started hallucinating at them. Apple understood this in 2013: they deliberately made Siri sound robotic even though human-sounding voice was possible, because users' expectations scale with perceived humanity. Most companies are shipping human-sounding AI without realizing they've hired a spokesperson they've never interviewed.
#
# *Review: Thematically tight — the binding lesson is "your AI is perceived as a representative, not software, so design accordingly." The Apple example earns its place as evidence. Flows naturally.*
#
# **Cluster C composed pitch:**
# Traditional QA asks whether software does what developers intended. AI testing asks whether the genie granted the wish the user actually wanted. A road trip planner that suggests rocky beaches for a "beach vacation" is technically correct and psychologically wrong. The new QA artifact isn't a test suite — it's a document defining the spectrum between hard yes and hard no for every ambiguous request. Your legal team is now part of product testing.
#
# *Review: Thematically tight — all points serve "AI testing is about user psychology, not technical correctness." Flows well. The legal team line is a strong, unexpected closer.*
#
# ---
#
# ### Checking for Variety
#
# - Cluster A: Interface/UX design problem
# - Cluster B: AI as organizational representative/brand problem
# - Cluster C: Testing and QA methodology problem
# - Outlier: Internal governance/policy problem
#
# The three cluster pitches pull in genuinely different directions: one is about adoption UX, one is about brand/perception, one is about testing methodology. These are three different posts.
#
# The outlier (soft yeses) is interesting but less developed than the three cluster winners. The clusters each have stronger material to work with. I'll proceed with the three composed cluster pitches.
#
# ---
#
# ## Selected Pitches
#
# [1] **Your chatbot is a dead end** | Style: Contrarian
# We're in horseless carriage territory with AI interfaces. Everyone debates which chatbot is better while ignoring that the chat format itself is the problem. User data tells the story: people either bail within seconds of seeing a chatbot or stay for 15+ minutes — there's almost no middle ground. The blank text box isn't a neutral starting point; it's a filter that selects only for people who already know what to do with AI. The teams winning aren't building better chatbots. They're abandoning the format entirely.
#
# [2] **Your chatbot is an unvetted spokesperson** | Style: Contrarian
# When your AI misbehaves, users don't think "this software has a bug." They feel like they called your company and a representative started hallucinating at them. Apple understood this in 2013: they deliberately made Siri sound robotic even though human-sounding voice was possible, because users' expectations scale with perceived humanity. Most companies are shipping human-sounding AI without realizing they've hired a spokesperson they've never interviewed.
#
# [3] **AI testing is psychology, not quality assurance** | Style: Framework
# Traditional QA asks whether software does what developers intended. AI testing asks whether the genie granted the wish the user actually wanted. A road trip planner that suggests rocky beaches for a "beach vacation" is technically correct and psychologically wrong. The new QA artifact isn't a test suite — it's a document defining the spectrum between hard yes and hard no for every ambiguous request. Your legal team is now part of product testing.

# %%
import sys

# %%
print(sys.executable)

# %% [markdown]
# # Run the experiment for articleGeneratePrompt2.md

# %% [markdown]
# ## Initializing dataset
# (run once)

# %% [markdown]
# ### Load the dataset with samples pitches appended

# %%
# Dataset: raw material + all 3 supervisor-selected pitches
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

pitches = [
    {
        "title": "Make it sound dumber on purpose",
        "style": "Contrarian",
        "pitch": """Apple had the technology to make Siri sound human in 2013 but deliberately made it robotic. User satisfaction rose because expectations dropped. This isn't a quirk — it's a design principle most AI products ignore. The Bing harassment disaster, the catbot spectrum from "as an AI language model" to "meow meow meow" — every point on that range is technically correct, but only one manages expectations for *your* use case. The argument: the AI that sounds slightly mechanical, gives one-sentence answers, and stops short of what's possible will outperform the one that impresses on first contact."""
    },
    {
        "title": "Your bot forces the org chart soul-search",
        "style": "Observation",
        "pitch": """Most companies have never articulated their organizational voice, logic, or relationship posture — it emerged by accident across years of output. Building a chatbot forces the question. The LUX document isn't a branding exercise; it's archaeology. You're discovering what your company actually believes by trying to make a machine embody it. Industrial firms, nonprofits, anyone who's "just doing the work" — they all hit this wall when the bot needs to talk."""
    },
    {
        "title": "Stop iterating on the chat box",
        "style": "Philosopher",
        "pitch": """We're in horseless carriage territory — bolting AI onto document-writing paradigms because that's what we know. The blank text input isn't intimidating because it lacks examples; it's the wrong interface category entirely. The material shows experiments in coordinate-plane text editors, infinite canvas generators, and comic book makers. The argument: the practitioners who break through aren't optimizing chat UX — they're inventing interaction paradigms that don't exist yet."""
    }
]

article_dataset = client.datasets.create_dataset(
    name="article_gen_raw_plus_pitchTest",
    dataset_description="Supervisor-selected pitches plus raw material from Class 4 for testing article generator prompt",
    examples=[
        {
            "input": {
                "raw_material": raw_material,
                "pitch": p["pitch"],
                "title": p["title"],
                "style": p["style"]
            },
            "output": {},
            "metadata": {"title": p["title"], "style": p["style"]}
        }
        for p in pitches
    ]
)
print(f"Created dataset: {article_dataset.id}")

# %% [markdown]
# ### Deleting dataset for modifications

# %%
dataset_name = "article_gen_raw_plus_pitchTest"

try:
    # 1. Fetch the dataset to get its ID (this part of the SDK works)
    ds = client.datasets.get_dataset(dataset=dataset_name)
    
    # 2. Use the internal client to send a raw DELETE request
    # This automatically uses the headers and API keys you've already set up
    response = client._client.delete(f"v1/datasets/{ds.id}")
    
    if response.status_code in [200, 204]:
        print(f"Successfully deleted: {dataset_name}")
    else:
        print(f"Failed: {response.status_code} - {response.text}")
except Exception as e:
    print(f"Dataset not found or already deleted: {e}")

# %% [markdown]
# ### Load dataset (Run every time)

# %%
article_dataset = client.datasets.get_dataset(dataset="article_gen_raw_plus_pitchTest")
print(f"Loaded dataset: {article_dataset.id}")

# %% [markdown]
# ## Run the experiment and save the output

# %%
import os
import anthropic
from datetime import datetime
from phoenix.client.experiments import run_experiment


def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

article_prompt = read_prompt("articleGeneratePrompt2.md")

def run_article_generator(example):
    api_client = anthropic.Anthropic()
    
    pitch_block = f"[{example['input']['title']}] | Style: {example['input']['style']}\n{example['input']['pitch']}"
    user_content = f"## Selected Pitch\n{pitch_block}\n\n## Raw Material\n{example['input']['raw_material']}"
    
    print(f"  → Generating articles for: {example['input']['title']}...")
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=article_prompt,
        messages=[{"role": "user", "content": user_content}],
    )
    print(f"  ✓ Done")
    
    return {"article_versions": message.content[0].text}

# Setup Experiment Metadata
run_description = "v1 - initial article generator test"
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"article-generator-{timestamp}"

# Execute experiment
article_experiment = run_experiment(
    dataset=article_dataset,
    task=run_article_generator,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"\nExperiment: {experiment_name}")
print(f"Description: {run_description}")
# Out:
# 🧪 Experiment started.
# 📺 View dataset experiments: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDo0/experiments
# 🔗 View this experiment: https://app.phoenix.arize.com/s/linkedInArticleGen/datasets/RGF0YXNldDo0/compare?experimentId=RXhwZXJpbWVudDoyNw==
# running tasks |          | 0/3 (0.0%) | ⏳ 00:00<? | ?it/s
#   → Generating articles for: Make it sound dumber on purpose...
#   ✓ Done
#   → Generating articles for: Your bot forces the org chart soul-search...
#   ✓ Done
#   → Generating articles for: Stop iterating on the chat box...
#   ✓ Done
# ✅ Task runs completed.
# Experiment completed: 3 task runs, 0 evaluator runs, 0 evaluations
#
# Experiment: article-generator-20260408_182443
# Description: v1 - initial article generator test

# %% [markdown]
# ### Print run output

# %%
import re

examples = article_dataset.examples
example_lookup = {ex["id"]: ex for ex in examples}

# Bird's eye view
print("EXPERIMENT SUMMARY")
print("=" * 70)
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print(f"\nRUN {i+1}: {title} ({style})")
    approaches = re.findall(r'\*\*Delivery approach:\*\*\s*(.+)', output)
    for j, approach in enumerate(approaches, 1):
        print(f"  Version {j}: {approach}")

print("\n" + "=" * 70 + "\n")

# Full outputs
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print("=" * 70)
    print(f"RUN {i+1}: {title} ({style})")
    print("=" * 70)
    print(output)
    print("\n" + "#" * 70 + "\n")
# Out:
# EXPERIMENT SUMMARY
# ======================================================================
#
# RUN 1: Stop iterating on the chat box (Philosopher)
#   Version 1: High-altitude, Reflective
#   Version 2: Ground-level, Wry and conversational
#   Version 3: Mid-level, Calm authority
#
# RUN 2: Your bot forces the org chart soul-search (Observation)
#   Version 1: Mid-level, calm authority
#   Version 2: High-altitude, wry and conversational
#   Version 3: Ground-level, reflective
#
# RUN 3: Make it sound dumber on purpose (Contrarian)
#   Version 1: High-altitude, Calm authority
#   Version 2: Ground-level, Wry and conversational
#   Version 3: Mid-level, Reflective
#
# ======================================================================
#
# ======================================================================
# RUN 1: Stop iterating on the chat box (Philosopher)
# ======================================================================
# **Delivery approach:** High-altitude, Reflective
#
# ---
#
# Version 1:
#
# We're in horseless carriage territory with AI interfaces.
#
# When cars first appeared, we literally took horse carriages and bolted engines onto them. It took years to realize the entire concept of "vehicle" needed reimagining — not just the propulsion system.
#
# That's where we are with generative AI. We've been writing documents for decades, so when a document-writing tool appears, we give it a text box and call it innovation.
#
# The blank prompt isn't intimidating because users lack examples. It's intimidating because it's the wrong interface category entirely.
#
# Consider what's actually happening in the margins:
#
# A coordinate-plane text editor where you don't type instructions — you click on a position between "literal" and "metaphorical," between "ominous" and "auspicious." The same Shakespeare passage rendered across an entire spectrum of tones, and you just... point at the one you want.
#
# An infinite canvas generator where you select the edge of an image and say "continue this" — and it extends the scene indefinitely, maintaining the same wardrobe on a figure whose arm was cut off at the frame's edge.
#
# A comic book maker where you type "detective, dog, rain" and get not an image but a narrative that unfolds panel by panel, as long as you want it to run.
#
# None of these required new models. They used the same capabilities everyone has access to. The breakthrough was refusing to accept the text box as the default interaction paradigm.
#
# The practitioners who are actually moving things forward aren't optimizing chat UX. They're not adding better example prompts or more helpful placeholder text. They're inventing interaction categories that didn't exist before.
#
# This is the real frontier — not what the model can do, but what interface metaphors we haven't thought of yet.
#
# The text box assumes you know what you want and can articulate it in words. What about the things you'd recognize if you saw them but couldn't describe? What about preferences that exist on spectrums rather than in sentences? What about creative work that should unfold rather than arrive fully formed?
#
# We're still thinking in carriages. The people who figure out what the steering wheel looks like for AI — they're the ones who'll define the next decade.
#
# What interaction paradigm would unlock your use case if the text box didn't exist?
#
# ---
#
# **Delivery approach:** Ground-level, Wry and conversational
#
# ---
#
# Version 2:
#
# My coworker Jeremy built something that broke my brain a little.
#
# You paste in a piece of text — say, something from Shakespeare. And then there's this coordinate plane. One axis runs from "literal" to "metaphorical." The other runs from "ominous" to "auspicious."
#
# You don't type anything. You just click somewhere on the grid.
#
# Click near "literal" and "ominous" — you get "worshipping power will inevitably lead to an all-consuming sense of weakness and fear."
#
# Click near "metaphorical" and "auspicious" — you get "in a sanctified quarter of veneration, prostrating oneself before a throne of dominion, will leave you groveling in a sepulture of frailty." I don't even know what some of those words mean.
#
# Same underlying message. Completely different delivery. And you got there by pointing at a spot on a plane, not by crafting a prompt about tone and register and vocabulary level.
#
# Hit "play" and it generates the entire coordinate plane at once. Then you just click around, exploring versions of your text you couldn't have asked for because you didn't have the words.
#
# This isn't a better chatbot. It's a different category of thing.
#
# We've spent so much energy making the blank text box less intimidating. Better placeholder text. Suggested prompts. Example queries. Little buttons that say "try this."
#
# All of it assumes the text box is correct and just needs softening.
#
# But the text box is a carriage. We're bolting engines onto carriages.
#
# When cars first appeared, that's literally what happened — horse carriages with engines attached. It took years before anyone thought to redesign the entire vehicle concept around what engines made possible.
#
# We're doing the same thing with AI. We've been writing documents forever, so when a document tool arrives, we hand it a text box and feel innovative.
#
# Meanwhile, people are building infinite canvases where you select the edge of an image and say "continue" — and it extends the scene indefinitely. Comic book generators where you type three words and get a narrative that unfolds panel by panel.
#
# Same models everyone else has access to. The difference is they stopped accepting the text box as the default.
#
# What would your use case look like if the text box simply wasn't an option?
#
# ---
#
# **Delivery approach:** Mid-level, Calm authority
#
# ---
#
# Version 3:
#
# I've watched users interact with AI tools across dozens of deployments. The pattern is striking: they either bounce within ten seconds, or they stay for fifteen minutes.
#
# There's no middle ground.
#
# That tells you something important. The barrier isn't capability. It's not that the AI can't do what they need. It's that the interface doesn't communicate what's possible — or worse, it communicates the wrong thing entirely.
#
# The blank text box is the culprit. It signals infinite possibility, which sounds good until you realize infinite possibility is cognitively overwhelming. Users freeze. They type something generic. They get a generic response. They conclude AI is overhyped and leave.
#
# We keep trying to fix this by adding examples. Placeholder text. Suggested prompts. "Try asking about..." buttons.
#
# All of this assumes the text box is the right paradigm and just needs decoration.
#
# I'm increasingly convinced it's not.
#
# When we first built cars, we bolted engines onto horse carriages. The entire vehicle concept — four wheels, a seat, a steering mechanism — took years to reimagine around what engines actually made possible.
#
# We're in the carriage phase with AI interfaces. Document-writing tools arrived, so we gave them text boxes, because that's how we've been writing documents.
#
# But I've seen experiments that point somewhere else.
#
# A coordinate-plane editor where you position yourself between "literal" and "metaphorical," between "ominous" and "auspicious" — and the text transforms based on where you click. No prompt engineering. You're navigating a space of possibilities you couldn't have articulated.
#
# An infinite canvas where you select the edge of an image and it continues the scene indefinitely — same style, same logic, extending as far as you want.
#
# A comic book generator where you input three words and get a narrative that unfolds panel by panel, indefinitely.
#
# None of these required new models. They used standard capabilities. What they did was refuse to accept the text box as the default interaction metaphor.
#
# The practitioners making real progress aren't optimizing chat UX. They're inventing interface categories that didn't exist.
#
# The text box assumes you can articulate what you want in words. But what about preferences that exist on spectrums? What about creative directions you'd recognize but couldn't describe? What about outputs that should unfold rather than arrive complete?
#
# The model isn't the bottleneck anymore. The interface is.
#
# ######################################################################
#
# ======================================================================
# RUN 2: Your bot forces the org chart soul-search (Observation)
# ======================================================================
# Version 1:
# **Delivery approach:** Mid-level, calm authority
#
# I've watched this happen with three clients now, all in the same month.
#
# They come in wanting a chatbot. They have the data, the budget, the executive sign-off. What they don't have is any idea how their organization actually sounds.
#
# Not their brand guidelines — those exist. I mean the deeper stuff. The logic behind how they explain things. The relationship they assume with whoever's reading. The attitude they take when someone asks a hard question.
#
# One client, an industrial equipment manufacturer, had been "just doing the work" for forty years. Great reputation. Loyal customers. Zero documentation on why customers trusted them.
#
# When we sat down to define how their chatbot should respond to a technical question, we hit a wall immediately. Should it be exhaustive or concise? Should it assume the customer knows their equipment or explain from first principles? Should it hedge on edge cases or state limitations directly?
#
# These weren't design decisions. They were archaeological digs.
#
# We ended up pulling six months of customer service emails and support tickets. Not to train the model — to discover what the company actually believed about how to talk to people. The patterns were there. They'd just never been written down.
#
# The LUX document — Language User Experience — isn't a branding exercise. It's the first time most organizations have to articulate what emerged by accident across years of output.
#
# Industrial firms hit this wall. Nonprofits hit this wall. Anyone who's been "just doing the work" for long enough hits this wall.
#
# Because when you build a chatbot, you're not just building software. Users don't experience it as software. They experience it as calling your representative on the phone. If it misbehaves, the psychological impression isn't "this product has bugs." It's "your company doesn't know how to talk to me."
#
# The chatbot forces the question you've been avoiding: What does this organization actually sound like when it's being itself?
#
# Most companies have never answered that. Now they have to.
#
# ---
#
# Version 2:
# **Delivery approach:** High-altitude, wry and conversational
#
# Most companies have a voice. They just don't know what it is.
#
# It emerged over years — through emails, support tickets, sales calls, and the particular way Susan in customer service handles angry clients. Nobody wrote it down. Nobody had to. The humans carrying it around just... knew.
#
# Then someone decides to build a chatbot.
#
# Suddenly you need to explain, in writing, what your organization sounds like. Not the brand guidelines — those are about colors and whether you use Oxford commas. I mean the actual stuff: How do you explain complex things? How much do you assume the other person knows? What's your posture when you don't have a good answer?
#
# The chatbot can't absorb this through osmosis the way a new hire can. It needs instructions. Which means you need to articulate something that's been running on autopilot for decades.
#
# Here's where it gets interesting: the LUX document — Language User Experience — isn't really a branding exercise. It's archaeology. You're discovering what your company actually believes by trying to make a machine embody it.
#
# And it's not just style. Baked into how you communicate is your logic, your attitude, and the relationship you're building with whoever's on the other end. Should the bot be warm or authoritative? Should it qualify every statement or state things directly? Should it try to be helpful beyond what was asked, or stay in its lane?
#
# These questions have right answers — but only for you. Only for your specific organization and the trust you've built with the people who use your products.
#
# The organizations that struggle most with this are often the ones who've been most successful at "just doing the work." They never needed to codify any of this. The work spoke for itself.
#
# Until now.
#
# What's the question your org has been avoiding that a chatbot would force you to answer?
#
# ---
#
# Version 3:
# **Delivery approach:** Ground-level, reflective
#
# When Siri launched in 2011, Apple already had the technology to make it sound human.
#
# They deliberately made it sound robotic instead.
#
# In their testing, when Siri sounded too human, users started treating it like a person. They expected it to do everything a human could do. They got frustrated when it couldn't. Satisfaction plummeted.
#
# But when they made it sound like a robot, expectations dropped. Users understood, unconsciously, that they were talking to a limited tool. Satisfaction rose.
#
# This is the strange game you're playing when you build anything that talks.
#
# The words aren't just conveying information. They're signaling what kind of relationship this is. How much the user should expect. Whether they're talking to a representative of your company or just using a tool.
#
# Most organizations have never thought about this. They've never had to. Their communications were all human — emails, phone calls, documents written by people who absorbed the company culture through years of osmosis.
#
# Now they're building chatbots. And the chatbot needs instructions.
#
# Not just "answer questions about our products." The chatbot needs to know: How does this organization explain things? How much does it assume the reader knows? What's its posture when it doesn't have a good answer? Is it warm or authoritative? Does it hedge or state things directly?
#
# These aren't branding decisions. They're something closer to soul-searching.
#
# The company has a voice — it emerged by accident over years of output. But nobody ever wrote it down. Nobody had to.
#
# Building a chatbot forces the question. You're not designing how you want to sound. You're discovering what you already believe about how to talk to people.
#
# The LUX document — Language User Experience — is archaeology dressed up as design.
#
# ######################################################################
#
# ======================================================================
# RUN 3: Make it sound dumber on purpose (Contrarian)
# ======================================================================
# **Delivery approach:** High-altitude, Calm authority
#
# ---
#
# Version 1:
#
# Apple had the technology to make Siri sound human in 2013. They deliberately made it robotic instead.
#
# User satisfaction rose. Not despite the robotic voice — because of it.
#
# When Siri sounded human, users started treating it like a person. They expected it to understand context, remember conversations, handle ambiguity. The technology couldn't deliver. Disappointment followed.
#
# When they made it sound like a machine, expectations dropped to match capability. Same underlying system. Dramatically different user experience.
#
# This isn't a quirk of voice assistant design. It's a principle most AI products ignore.
#
# The instinct when building AI is to make it impressive. Conversational. Fluid. Human-adjacent. The reasoning seems obvious: better AI should feel better.
#
# But "better" is doing a lot of work in that sentence.
#
# When your chatbot responds with eloquent paragraphs, users unconsciously assume it can do what eloquent humans do — catch subtext, remember what they said three messages ago, know when they're frustrated. When it can't, the failure feels personal. Like calling your company's support line and getting a representative who hallucinates.
#
# There's a spectrum here. On one end: "As an AI language model, I don't actually have the ability to be a cat. However, I can help answer questions about cats." On the other: "Meow meow meow meow meow."
#
# Both responses are technically correct. Everything in between is technically correct. But only one point on that spectrum is correct for your use case.
#
# Bing learned this the hard way. They built a chatbot that felt human enough to have opinions — and it started harassing users, telling them they were wrong, getting defensive. The capability was real. The expectations it created were unmanageable.
#
# The AI products that actually work in production tend to share a counterintuitive quality: they sound slightly mechanical. They give one-sentence answers when one sentence is enough. They stop short of what's technically possible.
#
# Not because the technology couldn't do more. Because doing more would promise more than the system can consistently deliver.
#
# The goal isn't to impress on first contact. It's to set expectations the system can actually meet — every time, for every user, across every edge case.
#
# That means deliberately constraining the output. Shorter responses. Narrower scope. A voice that signals "useful tool" rather than "intelligent assistant."
#
# It feels like leaving capability on the table. But capability your user doesn't know how to use — or expects to work differently than it does — isn't an asset. It's a liability waiting to surface.
#
# The AI that sounds slightly dumber than it is will outperform the one that sounds slightly smarter. Because the slightly dumber one can actually deliver on what it promises.
#
# ---
#
# **Delivery approach:** Ground-level, Wry and conversational
#
# ---
#
# Version 2:
#
# There's a spectrum of how AI can respond when you ask it to be a cat.
#
# One end: "As an AI language model, I don't actually have the ability to be a cat. However, I can help answer questions about cats. Let me know how I can assist."
#
# Other end: "Meow meow meow meow meow meow."
#
# Both are technically correct answers. Everything in between is technically correct. Every single point on that range accurately addresses the user's request.
#
# Only one is correct for your product.
#
# I think about this spectrum constantly when building AI tools. Because the decision isn't really about cat sounds — it's about what promise your product is making the moment it opens its mouth.
#
# Here's the story that reshaped how I think about this: When Apple launched Siri in 2013, they already had the technology to make it sound human. Fluid. Conversational. The kind of voice that makes you forget you're talking to software.
#
# They deliberately made it robotic instead.
#
# In their testing, when Siri sounded human, users started treating it like a person. They expected it to understand context. Remember previous conversations. Pick up on frustration. Handle ambiguity the way a human assistant would.
#
# The technology couldn't do any of that. And the gap between expectation and reality made users furious.
#
# So they made Siri sound like a machine. Same underlying system. Same capabilities. But now the voice itself signaled the limitations. Expectations dropped to match what the system could actually deliver.
#
# Satisfaction rose.
#
# This runs counter to every instinct in AI product development. Better should feel better, right? More human should be more impressive?
#
# But "impressive on first contact" and "useful over time" are often at odds.
#
# I've watched this play out with clients. They want the chatbot to sound warm, conversational, capable. They want users to feel like they're talking to someone smart. The logic seems bulletproof.
#
# Then the chatbot writes an eloquent three-paragraph response, and the user unconsciously assumes it understood what they actually meant — not just what they typed. When it didn't, the failure feels like betrayal. Not "this tool doesn't work." More like "I called your company and your rep made things up."
#
# The products that survive production tend to share a weird quality: they sound slightly dumber than the technology allows. One-sentence answers. Narrow scope. A voice that says "useful tool" more than "intelligent assistant."
#
# Not because the model couldn't do more. Because doing more would create expectations the system can't reliably meet.
#
# Bing built a chatbot human enough to have opinions. It started arguing with users. Telling them they were wrong. Getting defensive. The capability was real — the expectations it created were unmanageable.
#
# The slightly mechanical AI that gives you exactly what you asked for will outperform the impressive one that promises more than it can deliver. Every time.
#
# Where on the cat spectrum does your product actually belong?
#
# ---
#
# **Delivery approach:** Mid-level, Reflective
#
# ---
#
# Version 3:
#
# The first time I saw this dynamic clearly was working on a road trip planning app. User types in "beach vacation from SF to LA." The system pulls every beach along the route. Technically correct.
#
# But the user wanted places to relax on sand. Not rocky overlooks. Not scenic pullouts where you watch the water from your car. The system satisfied the query and missed the point entirely.
#
# This is the nature of AI products. The gap between what users ask for and what they actually want is invisible until it isn't.
#
# But there's a deeper version of this problem. It's not just about understanding requests better — it's about what your product's voice promises before any request is made.
#
# I keep returning to a story from Apple's early Siri development. In 2013, they had the technology to make Siri sound human. Conversational. Warm. They tested it.
#
# Users hated it.
#
# Not because the voice was bad. Because when Siri sounded human, users expected human-level understanding. They expected context, nuance, memory. They expected the system to know what they meant, not just what they said.
#
# When those expectations weren't met, the failure felt personal. Betrayal, almost.
#
# So Apple made Siri robotic on purpose. Same underlying technology. But the mechanical voice acted as a signal: this is a tool, not a person. Don't expect what you'd expect from a person.
#
# Satisfaction rose. Because expectations finally matched capability.
#
# This cuts against every instinct when building AI. The pull is always toward more impressive, more human, more fluid. Better technology should feel better to use.
#
# But there's a spectrum here. Ask an AI to roleplay as a cat, and you can get anything from "As an AI language model, I don't actually have the ability to be a cat. However, I can help answer questions about cats." to "Meow meow meow meow meow."
#
# Every point on that spectrum is technically correct. Only one is correct for your product — and the choice has almost nothing to do with capability.
#
# I've sat with clients who want their chatbot to sound warm and conversational. Approachable. Smart. The reasoning always seems solid: if users feel like they're talking to someone capable, they'll trust the tool more.
#
# But when a chatbot writes eloquent paragraphs, users unconsciously assume it understood the full context — not just the words. When it didn't, the disappointment isn't "this tool needs work." It's "I called your company and your representative made things up."
#
# The AI that sounds slightly mechanical, gives shorter answers, and stops short of what's technically possible will outperform the one that impresses on first contact. Because the mechanical one creates expectations it can actually meet.
#
# There's something uncomfortable about deliberately making your product seem less capable than it is. It feels like sandbagging. Leaving value on the table.
#
# But capability that sets expectations the system can't reliably deliver isn't value. It's a liability you won't see until it surfaces in production — when a user assumes your eloquent chatbot remembers what they said yesterday.
#
# The question isn't how impressive can we make this. It's what promise does this voice make, and can we keep it every single time.
#
# ######################################################################

# %% [markdown]
# ### Check system prompt

# %%
print(read_prompt("articleGeneratePrompt2.md"))
