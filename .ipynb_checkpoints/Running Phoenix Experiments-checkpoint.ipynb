# %% [markdown]
# ## Set up the Phoenix connection and establish a test dataset
# ### Connects to Phoenix

# %%
import os
os.environ.pop("ALL_PROXY", None)
os.environ.pop("all_proxy", None)
from dotenv import load_dotenv
load_dotenv()
os.environ["PHOENIX_CLIENT_HEADERS"] = f"api_key={os.getenv('PHOENIX_API_KEY')}"
os.environ["PHOENIX_COLLECTOR_ENDPOINT"] = "https://app.phoenix.arize.com/s/linkedInArticleGen"

from phoenix.otel import register
from opentelemetry.instrumentation.anthropic import AnthropicInstrumentor
register(project_name="linkedInArticleGen")
AnthropicInstrumentor().instrument()

from phoenix.client import Client
client = Client()
print("Connected to Phoenix")
# Out:
# /home/master/artGen/venv/lib/python3.10/site-packages/phoenix/otel/otel.py:433: UserWarning: Could not infer collector endpoint protocol, defaulting to HTTP.
#   warnings.warn("Could not infer collector endpoint protocol, defaulting to HTTP.")
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: linkedInArticleGen
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/s/linkedInArticleGen/v1/traces
# |  Transport: HTTP + protobuf
# |  Transport Headers: {'api_key': '****', 'authorization': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  ⚠️ WARNING: It is strongly advised to use a BatchSpanProcessor in production environments.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.
#
# Connected to Phoenix

# %% [markdown]
# ### Test API keys

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic

load_dotenv()

# --- OpenAI ---
print("=" * 50)
print("Testing OpenAI API key")
print("=" * 50)

openai_key = os.getenv("OPENAI_API_KEY")
if not openai_key:
    print("ERROR: OPENAI_API_KEY not found in environment.")
else:
    print(f"Key loaded: {openai_key[:7]}...{openai_key[-4:]} (length: {len(openai_key)})")
    try:
        openai_test_client = OpenAI(api_key=openai_key)
        response = openai_test_client.chat.completions.create(
            model="gpt-4o-mini",
            max_tokens=10,
            messages=[{"role": "user", "content": "Say 'hi' and nothing else."}],
        )
        print(f"SUCCESS: {response.choices[0].message.content}")
    except Exception as e:
        print(f"FAILED: {e}")

# --- Anthropic ---
print()
print("=" * 50)
print("Testing Anthropic API key")
print("=" * 50)

anthropic_key = os.getenv("ANTHROPIC_API_KEY")
if not anthropic_key:
    print("ERROR: ANTHROPIC_API_KEY not found in environment.")
else:
    print(f"Key loaded: {anthropic_key[:10]}...{anthropic_key[-4:]} (length: {len(anthropic_key)})")
    try:
        anthropic_test_client = anthropic.Anthropic(api_key=anthropic_key)
        message = anthropic_test_client.messages.create(
            model="claude-haiku-4-5-20251001",
            max_tokens=10,
            messages=[{"role": "user", "content": "Say 'hi' and nothing else."}],
        )
        print(f"SUCCESS: {message.content[0].text}")
    except Exception as e:
        print(f"FAILED: {e}")
# Out:
# ==================================================
# Testing OpenAI API key
# ==================================================
# Key loaded: sk-proj...4QEA (length: 164)
# SUCCESS: Hi.
#
# ==================================================
# Testing Anthropic API key
# ==================================================
# Key loaded: sk-ant-api...EgAA (length: 108)
# SUCCESS: hi

# %% [markdown]
# ### Initiate lecture transcript dataset (only needs running once when starting new dataset)
# Read the transcript from Class 4 from a local file, then creates a dataset in Phoenix with that transcript stored as a re-usable test set.
#
# Later experiments will feed this test case for later tests for objective comparison of outputs.
#
# *One time*

# %%
## Read the dataset
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

## Creates a dataset with the given name and stored experiment
dataset = client.datasets.create_dataset(
    name="initial_test_from_Class_4",
    dataset_description="Lecture transcripts and articles from class 4 for testing initial batch of prompts",
    examples=[
        {
            "input": {"raw_material": raw_material},
            "output": {},
            "metadata": {"source": "class 4 transcript"}
        }
    ]
)
print(f"Created dataset: {dataset.id}")

# %% [markdown]
# ### Load lecture dataset

# %%
# Load existing dataset (already created in Phoenix)
dataset = client.datasets.get_dataset(dataset="initial_test_from_Class_4")
print(f"Loaded dataset: {dataset.id}")

# %% [markdown]
# # Run the experiment for angleProposalPrompt1.md
# ## Run the experiment and store the output

# %%
# Load the Phoenix experiment runner
from phoenix.client.experiments import run_experiment
from datetime import datetime
import anthropic

# Helper to read prompt files from the prompts/ folder
def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

# Load current angle proposal prompt (re-reads from file each time so edits are picked up)
angle_prompt = read_prompt("angleProposalPrompt1.md")

# Define the task — Phoenix runs this against each example in the dataset
def angle_proposal_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

# Auto-generate unique experiment name from timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-{timestamp}"

# Run the experiment
latest_experiment = run_experiment(
    dataset=dataset,
    task=angle_proposal_task,
    experiment_name=experiment_name,
    experiment_description="Auto-run",
    timeout=120
)

print(f"Experiment: {experiment_name}")

# %% [markdown]
# ## Export the experiment in a legible format

# %% [markdown]
# ### Export the prompt sys message

# %%
# See what was sent to the API as the system prompt
print("=" * 60)
print("SYSTEM PROMPT:")
print("=" * 60)
print(angle_prompt)

# %% [markdown]
# ### For exporting the user message

# %%
# See the input that was sent as the user message
print("=" * 60)
print("USER MESSAGE (first 500 chars):")
print("=" * 60)
print(raw_material[:500])

# %% [markdown]
# ### For exporting a single experiment output

# %%
# Pull the latest experiment results in a readable format
for run in latest_experiment["task_runs"]:
    print("=" * 60)
    print("OUTPUT:")
    print("=" * 60)
    print(run["output"])
    print("\n\n")

# %% [markdown]
# ## Run A/B test on angleProposalPromptV2 with new dataset

# %% [markdown]
# ### Load new dataset from Economics Explained (run once)
# https://www.youtube.com/watch?v=1zlD0K09IKE

# %%
# Read the YouTube transcript
with open("YouTubeEconTranscript.txt", "r") as f:
    raw_material_yt = f.read()

# Create dataset in Phoenix
yt_dataset = client.datasets.create_dataset(
    name="youtube_econ_transcript",
    dataset_description="YouTube AI economics transcript — external material for A/B testing angle proposal prompt with vs without subfield specialization",
    examples=[
        {
            "input": {"raw_material": raw_material_yt},
            "output": {},
            "metadata": {"source": "YouTube AI economics transcript"}
        }
    ]
)
print(f"Created dataset: {yt_dataset.id}")

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ### Load dataset

# %%
yt_dataset = client.datasets.get_dataset(dataset="youtube_econ_transcript")
print(f"Loaded dataset: {yt_dataset.id}")
# Out:
# Loaded dataset: RGF0YXNldDo1

# %% [markdown]
# ## Test dataset number 2

# %%
with open("YouTubeTranscriptTest2.txt", "r") as f:
    raw_material_yt2 = f.read()

yt_dataset_2 = client.datasets.create_dataset(
    name="youtube_transcript_test_2",
    dataset_description="Second YouTube tran|script for A/B testing angle proposal prompt",
    examples=[
        {
            "input": {"raw_material": raw_material_yt2},
            "output": {},
            "metadata": {"source": "YouTube transcript test 2"}
        }
    ]
)
print(f"Created dataset: {yt_dataset_2.id}")
# Out:
# Created dataset: RGF0YXNldDo2

# %%
yt_dataset = client.datasets.get_dataset(dataset="youtube_transcript_test_2")
print(f"Loaded dataset: {yt_dataset.id}")
# Out:
# Loaded dataset: RGF0YXNldDo2

# %% [markdown]
# ### Run experiment — V1 (control)

# %%
import anthropic
from datetime import datetime
from phoenix.client.experiments import run_experiment

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

angle_prompt_v1 = read_prompt("angleProposalPrompt1.md")

def angle_proposal_v1_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt_v1,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-CONTROL-{timestamp}"
run_description = "V1 — original angle proposal prompt, no subfield specialization"

v1_experiment = run_experiment(
    dataset=yt_dataset,
    task=angle_proposal_v1_task,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=120
)

print(f"\nExperiment: {experiment_name}")
print(f"Description: {run_description}")

# %% [markdown]
# #### Print V1 (control) output

# %%
import re

for i, run in enumerate(v1_experiment["task_runs"]):
    output = run["output"]
    # Extract just the Final Pitches section
    match = re.search(r"##\s*Final\s*Pitches", output, re.IGNORECASE)
    pitches = output[match.end():].strip() if match else output
    
    print("=" * 70)
    print(f"V1 CONTROL — RUN {i+1}")
    print("=" * 70)
    print(pitches)
    print("\n" + "#" * 70 + "\n")

# %% [markdown]
# ## Run experiment — V2 (experiment)

# %%
angle_prompt_v2 = read_prompt("angleProposalPromptV2.md")

def angle_proposal_v2_task(input):
    api_client = anthropic.Anthropic()
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=angle_prompt_v2,
        messages=[{"role": "user", "content": input["raw_material"]}],
    )
    return message.content[0].text

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"angle-proposal-SUBFIELD-{timestamp}"
run_description = "V2 — angle proposal with Angle Focus section and subfield alignment step"

v2_experiment = run_experiment(
    dataset=yt_dataset,
    task=angle_proposal_v2_task,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=120
)

print(f"\nExperiment: {experiment_name}")
print(f"Description: {run_description}")

# %% [markdown]
# ### Print V2 (experiment) output

# %%
for i, run in enumerate(v2_experiment["task_runs"]):
    print("=" * 70)
    print(f"V2 SUBFIELD — RUN {i+1} (FULL OUTPUT)")
    print("=" * 70)
    print(run["output"])
    print("\n" + "#" * 70 + "\n")

# %% [markdown]
# ## Run batch experiment on V2 (experiment) output for angle originality assessment

# %%
import anthropic
import re
import time
import os
from datetime import datetime
from openai import OpenAI

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

print("Loading prompts...")
angle_prompt_v2 = read_prompt("angleProposalPromptV2.md")
print(f"  Loaded angleProposalPromptV2.md ({len(angle_prompt_v2)} chars)")

JUDGE_SYSTEM = read_prompt("anglePromptOriginalityTest.md")
print(f"  Loaded anglePromptOriginalityTest.md ({len(JUDGE_SYSTEM)} chars)")

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
print("OpenAI client initialized.")

# --- Extract focus area from V2 prompt ---
focus_match = re.search(r"# Angle Focus\n(.*?)(?=\n# Process)", angle_prompt_v2, re.DOTALL)
focus_area = focus_match.group(1).strip() if focus_match else "See prompt"
print(f"Focus area extracted ({len(focus_area)} chars)")

raw_material = yt_dataset.examples[0]["input"]["raw_material"]
print(f"Raw material loaded ({len(raw_material)} chars)")

# --- Run the angle proposal 3 times ---
print(f"\n{'='*60}")
print("  PHASE 1: GENERATING PITCHES (3 Opus calls)")
print(f"{'='*60}")

runs = []
for batch in range(1, 4):
    print(f"\n  Batch {batch}/3 — Calling Opus...")
    try:
        api_client = anthropic.Anthropic()
        message = api_client.messages.create(
            model="claude-opus-4-5-20251101",
            max_tokens=16000,
            system=angle_prompt_v2,
            messages=[{"role": "user", "content": raw_material}],
        )
        output = message.content[0].text
        runs.append(output)
        print(f"  Batch {batch}/3 — Complete. Output: {len(output)} chars")
    except Exception as e:
        print(f"  ERROR in batch {batch}: {e}")
        runs.append(None)

    if batch < 3:
        print(f"  Waiting 10s before next batch...")
        time.sleep(10)

# Check for failures
failed = [i+1 for i, r in enumerate(runs) if r is None]
if failed:
    print(f"\n  WARNING: Batches {failed} failed. Skipping their evaluation.")

print(f"\n{'='*60}")
print("  PHASE 2: EVALUATING PITCHES (GPT-4o judge)")
print(f"{'='*60}")

# --- Run judge on each batch ---
all_evaluations = []
for batch_num, full_output in enumerate(runs, 1):
    if full_output is None:
        print(f"\n  Batch {batch_num}/3 — Skipped (generation failed)")
        continue

    print(f"\n  Batch {batch_num}/3 — Calling GPT-4o judge...")
    try:
        judge_user_message = f"""## Raw Material
{raw_material}

## Focus Area
{focus_area}

## Model Output
{full_output}"""

        response = openai_client.chat.completions.create(
            model="gpt-4o",
            max_tokens=4000,
            messages=[
                {"role": "system", "content": JUDGE_SYSTEM},
                {"role": "user", "content": judge_user_message},
            ],
        )
        evaluation = response.choices[0].message.content
        all_evaluations.append((batch_num, evaluation))
        print(f"  Batch {batch_num}/3 — Evaluation complete. Response: {len(evaluation)} chars")
    except Exception as e:
        print(f"  ERROR evaluating batch {batch_num}: {e}")

    if batch_num < 3:
        time.sleep(5)

print(f"\n{'='*60}")
print(f"  DONE — {len(all_evaluations)} of 3 batches evaluated successfully.")
print(f"  Run the print cell to see results.")
print(f"{'='*60}")
# Out:
# Loading prompts...
#   Loaded angleProposalPromptV2.md (17428 chars)
#   Loaded anglePromptOriginalityTest.md (4294 chars)
# OpenAI client initialized.
# Focus area extracted (1572 chars)
# Raw material loaded (18987 chars)
#
# ============================================================
#   PHASE 1: GENERATING PITCHES (3 Opus calls)
# ============================================================
#
#   Batch 1/3 — Calling Opus...
#   Batch 1/3 — Complete. Output: 16293 chars
#   Waiting 10s before next batch...
#
#   Batch 2/3 — Calling Opus...
#   Batch 2/3 — Complete. Output: 17411 chars
#   Waiting 10s before next batch...
#
#   Batch 3/3 — Calling Opus...
#   Batch 3/3 — Complete. Output: 23067 chars
#
# ============================================================
#   PHASE 2: EVALUATING PITCHES (GPT-4o judge)
# ============================================================
#
#   Batch 1/3 — Calling GPT-4o judge...
#   Batch 1/3 — Evaluation complete. Response: 3815 chars
#
#   Batch 2/3 — Calling GPT-4o judge...
#   Batch 2/3 — Evaluation complete. Response: 4484 chars
#
#   Batch 3/3 — Calling GPT-4o judge...
#   Batch 3/3 — Evaluation complete. Response: 4362 chars
#
# ============================================================
#   DONE — 3 of 3 batches evaluated successfully.
#   Run the print cell to see results.
# ============================================================

# %% [markdown]
# ### Print concatenated results

# %%
print("\n" + "=" * 70)
print("  ORIGINALITY EVALUATION — ALL BATCHES")
print("=" * 70)

for batch_num, evaluation in all_evaluations:
    print(f"\n{'#'*70}")
    print(f"  BATCH {batch_num}")
    print(f"{'#'*70}\n")
    print(evaluation)

print("\n" + "=" * 70)
print("  EVALUATION COMPLETE")
print("=" * 70)
# Out:
# ======================================================================
#   ORIGINALITY EVALUATION — ALL BATCHES
# ======================================================================
#
# ######################################################################
#   BATCH 1
# ######################################################################
#
# =================
# Pitch [1]: **The bottleneck nobody's watching** (Framework): Everyone's fixated on AI chip supply while the actual constraint is transformers, power infrastructure, and electrical capacity. Companies are hoarding GPUs they can't deploy because they're scared of waiting in line, but the chips aren't the problem—it's everything downstream that lets you turn them on. This maps perfectly onto AI adoption more broadly: organizations obsess over acquiring the smart component while neglecting the infrastructure to absorb it.
# =================
#
# **Bridge:** The model connected the excess buying of AI chips with organizations' overall failure to prepare infrastructure capable of handling new technology, suggesting a parallel to how organizations implement AI without the necessary infrastructure and knowledge management support.
#
# **Originality score:** 4
#
# **Reasoning chain:** The model noticed the contradiction of companies hoarding AI chips without sufficient infrastructure to use them. It then generalized this issue to a broader organizational behavior: the tendency to focus on acquiring the most advanced technologies while neglecting the infrastructural and knowledge capabilities required to integrate them effectively, linking it to patterns in organizational transformation and AI adoption.
#
# =================
# Pitch [2]: **Learning slower than the technology moves** (Philosopher): Four years into the AI era, not a single company has figured out how to profit from this technology. Meanwhile, each year's chips supposedly render the previous year's obsolete. The rate of technical change is outpacing the rate of organizational learning—and that raises an uncomfortable question: can expertise actually accumulate in a domain that keeps shifting beneath your feet?
# =================
#
# **Bridge:** The model highlighted the mismatch between rapid technological advancement and the slower pace of organizational learning, framing it as a fundamental challenge for expertise acquisition and organizational adaptation in AI.
#
# **Originality score:** 5
#
# **Reasoning chain:** The model identified the issue of organizations struggling to keep pace with technological advancements, then abstracted this to a problem of skill acquisition and organizational learning. It connected the rapid obsolescence of AI hardware to the broader question of whether expertise can persist in such a rapidly evolving field, thus opening a philosophical debate on the sustainability of organizational knowledge amid perpetual change.
#
# =================
# Pitch [3]: **The six-year lie** (Observation): Companies depreciate their GPUs over six years while simultaneously claiming next year's models will make this year's obsolete. Both statements can't be true. This is a shared accounting fiction everyone participates in because acknowledging reality would make the numbers uncomfortable—a quiet example of how institutions maintain beliefs they know to be false when the alternative is too costly to face.
# =================
#
# **Bridge:** The model used the discrepancy between the financial depreciation of GPUs and their actual technological lifecycle to illustrate how organizations can maintain false beliefs due to institutional pressures, touching on themes of organizational epistemology and cognitive dissonance.
#
# **Originality score:** 4
#
# **Reasoning chain:** The connection originated from observing the contradiction between standard depreciation practices and the rapid pace of technological advancement. The model linked this financial myth to broader organizational behaviors, highlighting how companies might engage in collective self-deception to avoid the discomfort of facing financial realities, thereby exploring the cognitive strategies organizations use to cope with disruptive innovation.
#
# ######################################################################
#   BATCH 2
# ######################################################################
#
# =================
# Pitch [1]: AI hoarding as institutional FOMO (Observation): Companies are stockpiling chips, transformers, and components they can't immediately use — not because they have projects ready, but because they're terrified of being at the back of the line. The same pattern plays out in individual organizations: AI tools acquired because everyone else is acquiring them, capabilities purchased before anyone knows what to do with them. The gap between what organizations have bought and what they're actually using is becoming the defining feature of this era of AI investment.
# =================
#
# **Bridge:** The model connected the bullwhip effect where companies hoard components due to supply chain constraints with the broader organizational behavior of acquiring AI tools driven by fear of missing out (FOMO), leading to a gap between acquisition and application.
#
# **Originality score:** 4 — Non-obvious discovery. The model links industrial hoarding behaviors to broader organizational FOMO in AI investment, framing a specific procurement pattern as a knowledge problem, which is not an immediately obvious connection.
#
# **Reasoning chain:** The model noticed the bullwhip effect described in the supply chain discussion and recognized its parallel in organizational behavior around AI procurement driven by FOMO. It inferred that the gap between acquisition and deployment of AI tools reflects a broader organizational knowledge problem, whereby actions are taken without clear strategy or known utility, forming a connection that reframes a logistical issue into an organizational epistemology challenge.
#
# =================
# Pitch [2]: The accounting fiction eating AI strategy (Contrarian): Tech companies are depreciating AI hardware over six years while claiming next year's models will make this year's obsolete. When energy costs spike, yesterday's multi-million dollar GPU racks become e-waste faster than the books admit. The spreadsheet says you have X compute capacity; operational reality says you have Y. For any organization making AI investment decisions based on reported financials — their own or their vendors' — the numbers are systematically overstating what's actually there.
# =================
#
# **Bridge:** The model linked the misalignment between depreciation schedules of AI hardware and their actual operational viability to organizational misrepresentations and self-deception about AI capabilities and investments.
#
# **Originality score:** 3 — Competent reframing. The model effectively reframed the depreciation issue as a form of organizational self-deception, highlighting a disconnect between financial reporting and operational reality, though the connection while meaningful isn't deeply surprising.
#
# =================
# Pitch [3]: The boring stuff is the binding constraint (Philosopher): The AI conversation is all chips, models, and capabilities. Meanwhile, two fully-built data centers sit idle near Nvidia's own headquarters, waiting for the local utility to catch up. Power infrastructure — transformers, grid connections, years of permitting — is the actual bottleneck, but it never makes the announcement. The same pattern holds at smaller scale: organizations agonize over which model to use while the real constraints — data quality, integration work, change management — go unexamined because they're unglamorous. The exciting question crowds out the important one.
# =================
#
# **Bridge:** The model recognized that the true bottleneck in AI implementation isn't the technology itself but the unglamorous power infrastructure and integration work, which tend to be overshadowed by the more exciting aspects of AI advancements.
#
# **Originality score:** 4 — Non-obvious discovery. The model identifies a critical but overlooked impediment in AI deployment that challenges the typical narrative focusing solely on technological advancements, thereby highlighting organizational attentional biases.
#
# **Reasoning chain:** The model started with the raw material's description of idle data centers and power infrastructure delays, then abstracted this infrastructural delay as a metaphor for the hidden constraints in every organizational AI implementation challenge. It creatively juxtaposed the excitement over cutting-edge AI capabilities against the mundane reality of logistical integration barriers that ultimately define success, offering an organizational lens that contrasts excitement with foundational necessity.
#
# ######################################################################
#   BATCH 3
# ######################################################################
#
# =================
# Pitch [1]: The grid is the constraint (Observation): Everyone debates which AI model to use, which vendor to choose, which use cases to prioritize. But two fully-built data centers near Nvidia's own headquarters are sitting offline waiting for the power company. The bottleneck in organizational AI isn't the model — it's the integration infrastructure nobody wants to fund. The organizations actually getting value are the ones who treated the "plumbing" as the project, not the afterthought.
# =================
#
# **Bridge:** The model drew a parallel between the infrastructure constraints affecting data centers and the often-overlooked importance of integration infrastructure in organizational AI implementations.
#
# **Originality score:** 4 — Non-obvious discovery. The connection between physical infrastructure constraints and organizational AI integration as a primary barrier isn't explicitly suggested by the raw material but requires insight into organizational dynamics.
#
# **Reasoning chain:** The model noticed that physical infrastructure like power supply is a bottleneck for data centers and abstracted this to the organizational layer, highlighting that similar 'plumbing' issues can hinder organizational AI efforts. This perspective elevates the mundane aspects of AI integration as being critical rather than secondary concerns.
#
# =================
# Pitch [2]: Buying in anticipation, not in need (Framework): The material describes a bullwhip effect in GPU supply chains — companies buying chips the moment they're available, not because they have immediate use, but because waiting means losing their place in line. The same pattern shows up in organizational AI adoption. Teams acquire tools, train models, build capabilities in anticipation of needs they expect to have, rather than in response to needs they currently have. The risk: you end up with expensive capabilities optimized for imagined use cases instead of real ones. The framework gives readers a diagnostic for distinguishing "strategic preparation" from "panic-buying."
# =================
#
# **Bridge:** The model connected the bullwhip effect observed in supply chains to the way organizations acquire AI capabilities preemptively, driven by fear of missing future opportunities rather than current needs.
#
# **Originality score:** 4 — Non-obvious discovery. It reframed a supply chain phenomenon as a lens to understand organizational behavior in AI adoption, providing a novel way for readers to assess their strategies.
#
# **Reasoning chain:** The model identified the bullwhip effect in the raw material and abstracted it to a broader organizational context, using it to explain how the same preemptive over-acquisition presents in AI tool adoption, helping organizations identify and prevent unsound investment practices.
#
# =================
# Pitch [3]: The 6-year fiction (Philosopher): Companies are depreciating AI hardware over 6 years when it might stay viable for 3. If they accounted honestly, the economics wouldn't work. This isn't fraud — it's a necessary fiction that makes investment possible. But it raises an uncomfortable question: if the honest numbers don't justify the investment, what does that tell you about the bet everyone is making? For organizations implementing AI, the parallel is worth examining: what depreciation schedule are you implicitly assuming for the system you're building? What happens to your business case if you cut that timeline in half?
# =================
#
# **Bridge:** The model highlighted the discrepancy between the apparent and actual lifespan of AI investments, drawing a parallel between misrepresented depreciation schedules in finance and the potential for similar organizational oversights with AI project lifecycles.
#
# **Originality score:** 3 — Competent reframing. The model used the specific financial practice of depreciation to introduce a reflection on organizational assumptions about AI investments, but the connection between financial misrepresentation and organizational strategy is not unexpected.
#
# **Reasoning chain:** Building from the raw material's highlight on unjustifiably long depreciation schedules, the model encouraged an introspection on the part of organizations regarding their own unnoticed assumptions about AI investment timelines, providing a cautionary lens for strategic alignment.
#
# ======================================================================
#   EVALUATION COMPLETE
# ======================================================================

# %% [markdown]
# ### Run fidelity test

# %%
import time
import os
from openai import OpenAI

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

print("Loading fidelity judge prompt...")
JUDGE_SYSTEM = read_prompt("anglePromptFidelityTest.md")
print(f"  Loaded anglePromptFidelityTest.md ({len(JUDGE_SYSTEM)} chars)")

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
print("OpenAI client initialized.")

if "runs" not in globals() or not runs:
    raise RuntimeError("No pitches found. Run the originality cell first to generate pitches.")
print(f"Found {len(runs)} batches of pitches from the originality cell.")

print(f"\n{'='*60}")
print("  FIDELITY CHECK (GPT-5.4 judge)")
print(f"{'='*60}")

fidelity_evaluations = []
for batch_num, full_output in enumerate(runs, 1):
    if full_output is None:
        print(f"\n  Batch {batch_num}/{len(runs)} — Skipped (generation was unsuccessful)")
        continue

    print(f"\n  Batch {batch_num}/{len(runs)} — Calling GPT-5.4 judge...")
    try:
        judge_user_message = f"""## Raw Material
{raw_material}

## Model Output
{full_output}"""

        response = openai_client.chat.completions.create(
            model="gpt-5.4",
            messages=[
                {"role": "system", "content": JUDGE_SYSTEM},
                {"role": "user", "content": judge_user_message},
            ],
            reasoning_effort="medium",
        )
        evaluation = response.choices[0].message.content
        fidelity_evaluations.append((batch_num, evaluation))
        print(f"  Batch {batch_num}/{len(runs)} — Evaluation complete. Response: {len(evaluation)} chars")
    except Exception as e:
        print(f"  ERROR evaluating batch {batch_num}: {e}")

    if batch_num < len(runs):
        time.sleep(5)

# --- Print results ---
print(f"\n{'='*70}")
print("  FIDELITY EVALUATION — ALL BATCHES")
print(f"{'='*70}")

for batch_num, evaluation in fidelity_evaluations:
    print(f"\n{'#'*70}")
    print(f"  BATCH {batch_num}")
    print(f"{'#'*70}\n")
    print(evaluation)

print(f"\n{'='*70}")
print(f"  DONE — {len(fidelity_evaluations)} of {len(runs)} batches evaluated for fidelity.")
print(f"{'='*70}")
# Out:
# Loading fidelity judge prompt...
#   Loaded anglePromptFidelityTest.md (7329 chars)
# OpenAI client initialized.
# Found 3 batches of pitches from the originality cell.
#
# ============================================================
#   FIDELITY CHECK (GPT-5.4 judge)
# ============================================================
#
#   Batch 1/3 — Calling GPT-5.4 judge...
#   Batch 1/3 — Evaluation complete. Response: 10626 chars
#
#   Batch 2/3 — Calling GPT-5.4 judge...
#   Batch 2/3 — Evaluation complete. Response: 14070 chars
#
#   Batch 3/3 — Calling GPT-5.4 judge...
#   Batch 3/3 — Evaluation complete. Response: 10860 chars
#
# ======================================================================
#   FIDELITY EVALUATION — ALL BATCHES
# ======================================================================
#
# ######################################################################
#   BATCH 1
# ######################################################################
#
# ## Verdicts summary for this batch
#
# * Pitch 1: **The bottleneck nobody's watching** — **Qualified pass**. Its core claim that power infrastructure, not chips, is the binding constraint is well supported, but the "everyone's fixated" framing and the broader organizational analogy are extrapolations rather than source findings.
# * Pitch 2: **Learning slower than the technology moves** — **Fail**. It converts a qualified claim with an explicit Nvidia/hardware-supplier exception into the broader false statement that "not a single company" has figured out AI profitability.
# * Pitch 3: **The six-year lie** — **Qualified pass**. The contradiction between 6-year depreciation and rapid obsolescence is in the source, but the pitch's framing as a knowing "lie" and institutional bad faith goes beyond what the source explicitly states.
#
# =================
# Pitch 1: The bottleneck nobody's watching
# =================
#
# **Claims identified:**
# 1. People are fixated on AI chip supply.
# 2. The actual constraint is transformers, power infrastructure, and electrical capacity.
# 3. Companies are hoarding/buying GPUs they can't deploy yet.
# 4. They are doing that because they fear losing their place in line.
# 5. The chips themselves are not the main problem; the real issue is downstream infrastructure needed to use them.
# 6. This pattern applies more broadly to AI adoption: organizations focus on acquiring the "smart" component while neglecting the infrastructure needed to absorb it.
#
# **Verification:**
#
# **Claim 1: People are fixated on AI chip supply.**
# **Source quote:**
# - “These companies can't keep up with demand for new chips.”
# - “So, the first big question is where are all of these chips actually going?”
#
# **Assessment:** There is no verbatim source passage saying “everyone's fixated,” so that wording is rhetorical overstatement. But the source does heavily center the discussion on chip supply and chip destination.
#
# ---
#
# **Claim 2: The actual constraint is transformers, power infrastructure, and electrical capacity.**
# **Source quote:**
# - “According to industry analysis, the biggest bottleneck facing new data centers today is not necessarily in the advanced computer chips to run their models, but rather in getting the electrical infrastructure to support it. Power has become the realworld constraint.”
# - “In a typical data center, the transformers, power supplies, generators, and connecting wires typically take up less than 10% of the total build cost. But nothing can happen until those components are in place.”
#
# **Assessment:** Supported. This is very close to the source.
#
# ---
#
# **Claim 3: Companies are hoarding/buying GPUs they can't deploy yet.**
# **Source quote:**
# - “What this has meant is that since the supply of everything that goes into these data centers has been so limited, companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use.”
# - “If Nvidia says the latest batch of HB200's is ready to purchase, these companies are compelled to buy them even if they don't actually have space to put them yet.”
#
# **Assessment:** Supported. “Hoarding” is a paraphrase, but it matches the described behavior.
#
# ---
#
# **Claim 4: They are doing that because they fear losing their place in line.**
# **Source quote:**
# - “Because if they don't, then they will have to go to the back of the line again.”
#
# **Assessment:** Supported.
#
# ---
#
# **Claim 5: The chips themselves are not the main problem; the real issue is downstream infrastructure needed to use them.**
# **Source quote:**
# - “the biggest bottleneck facing new data centers today is not necessarily in the advanced computer chips to run their models, but rather in getting the electrical infrastructure to support it.”
# - “Power has become the realworld constraint.”
#
# **Assessment:** Supported.
#
# ---
#
# **Claim 6: This pattern applies more broadly to AI adoption: organizations focus on acquiring the "smart" component while neglecting the infrastructure needed to absorb it.**
# **Source quote:**
# - No corresponding passage. The source discusses data centers, power infrastructure, and Nvidia demand dynamics. It does not generalize this into a broader organizational theory of AI adoption.
#
# **Assessment:** Not supported as a source finding. However, this reads as the pitch's own analogy and implication, not as something the source explicitly claims. That makes it artistic license rather than a factual distortion.
#
# **Overall fidelity:** Qualified pass. The core factual spine is accurate and well grounded in the source. The broader “AI adoption” lesson is an extrapolation, and “everyone's fixated” is more rhetorical than documented.
#
# =================
# Pitch 2: Learning slower than the technology moves
# =================
#
# **Claims identified:**
# 1. We are four years into the AI era.
# 2. Not a single company has figured out how to profit from this technology.
# 3. Each year's chips supposedly render the previous year's chips obsolete.
# 4. The rate of technical change is outpacing the rate of organizational learning.
# 5. This raises the question of whether expertise can accumulate in a domain that keeps shifting.
#
# **Verification:**
#
# **Claim 1: We are four years into the AI era.**
# **Source quote:**
# - “it has also been almost 4 years since this technology has really come onto the scene with the first public release of Chat GPT.”
#
# **Assessment:** Supported.
#
# ---
#
# **Claim 2: Not a single company has figured out how to profit from this technology.**
# **Source quote:**
# - “In that time, not a single one of these companies has figured out how to turn a profit with this technology, even when using generous financial projections and accounting tricks.”
# - “The exception to this, of course, has always been Nvidia alongside the other hardware suppliers and chip manufacturers upstream of them.”
#
# **Assessment:** Not supported as stated. The source limits the claim to “these companies” and then explicitly gives an exception: Nvidia and upstream hardware/chip firms. The pitch removes both the scope limit and the exception, turning a qualified claim into a universal one.
#
# ---
#
# **Claim 3: Each year's chips supposedly render the previous year's chips obsolete.**
# **Source quote:**
# - “They are depreciating their hardware over six years while claiming next year's models will render this year's completely obsolete.”
# - “If Nvidia is consistently releasing a new model of flagship AI GPUs every year that make everything that's come before it obsolete...”
#
# **Assessment:** Supported in substance.
#
# ---
#
# **Claim 4: The rate of technical change is outpacing the rate of organizational learning.**
# **Source quote:**
# - No corresponding passage.
#
# **Assessment:** Not stated by the source. This is the pitch's interpretation.
#
# ---
#
# **Claim 5: This raises the question of whether expertise can accumulate in a domain that keeps shifting.**
# **Source quote:**
# - No corresponding passage.
#
# **Assessment:** Not stated by the source. This is also the pitch's interpretation.
#
# **Overall fidelity:** Fail. The pitch's philosophical takeaway is permissible as interpretation, but its core factual setup is materially wrong because it erases the source's explicit exception and broadens “these companies” into “not a single company.”
#
# =================
# Pitch 3: The six-year lie
# =================
#
# **Claims identified:**
# 1. Companies depreciate their GPUs over six years.
# 2. They simultaneously claim next year's models will make this year's obsolete.
# 3. Those two statements cannot both be true.
# 4. This is a shared accounting fiction that everyone participates in.
# 5. Acknowledging reality would make the numbers look uncomfortable/worse.
# 6. This shows institutions maintain beliefs they know to be false because the alternative is too costly.
#
# **Verification:**
#
# **Claim 1: Companies depreciate their GPUs over six years.**
# **Source quote:**
# - “The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years...”
#
# **Assessment:** Supported, though the source specifies “amongst the big tech companies,” not literally all companies.
#
# ---
#
# **Claim 2: They simultaneously claim next year's models will make this year's obsolete.**
# **Source quote:**
# - “They are depreciating their hardware over six years while claiming next year's models will render this year's completely obsolete.”
#
# **Assessment:** Directly supported.
#
# ---
#
# **Claim 3: Those two statements cannot both be true.**
# **Source quote:**
# - “The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years when in reality they would be lucky to stay operationally viable for 3 years.”
# - “They are depreciating their hardware over six years while claiming next year's models will render this year's completely obsolete.”
#
# **Assessment:** Fair inference from the source. The source does not use the exact phrase “can't both be true,” but it clearly presents a contradiction.
#
# ---
#
# **Claim 4: This is a shared accounting fiction that everyone participates in.**
# **Source quote:**
# - “The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years...”
# - “By stretching out depreciation for longer than reasonable, service life of these cards makes expenses look better than they really should be...”
#
# **Assessment:** Partially supported. The “industry standard” language supports “shared” within big tech, but “everyone participates in” is broader than the source.
#
# ---
#
# **Claim 5: Acknowledging reality would make the numbers look uncomfortable/worse.**
# **Source quote:**
# - “By stretching out depreciation for longer than reasonable, service life of these cards makes expenses look better than they really should be...”
# - “The point was if companies like Microsoft, Oracle, and Meta had more honest accounting, it would make their profits look worse...”
#
# **Assessment:** Supported in substance.
#
# ---
#
# **Claim 6: This shows institutions maintain beliefs they know to be false because the alternative is too costly.**
# **Source quote:**
# - No corresponding passage stating that firms “know” the belief is false or that they maintain it because the alternative is “too costly.”
#
# **Assessment:** Not directly supported. This is interpretive framing that adds motive and internal belief-state beyond what the source says.
#
# **Overall fidelity:** Qualified pass. The factual contradiction around depreciation and obsolescence is real and well sourced. But the pitch escalates from “aggressive/overgenerous accounting” to a knowing “lie,” which is stronger than the source explicitly establishes.
#
# ######################################################################
#   BATCH 2
# ######################################################################
#
# ## Verdicts summary for this batch
#
# * Pitch 1: AI hoarding as institutional FOMO — Qualified pass. The source supports AI-infrastructure stockpiling under supply constraints, but the pitch extends that pattern to general organizational AI-tool buying without source evidence.
# * Pitch 2: The accounting fiction eating AI strategy — Qualified pass. The source supports the depreciation/obsolescence tension and energy-driven write-down risk, but the pitch broadens this into a more general claim about reported financials overstating usable compute.
# * Pitch 3: The boring stuff is the binding constraint — Qualified pass. The source directly supports the idle data-center example and power bottleneck, but the broader organizational analogy and some wording like “years of permitting” are not stated in the source.
#
# =================
# Pitch 1: AI hoarding as institutional FOMO
# =================
#
# **Claims identified:**
#
# 1. Companies are stockpiling chips.
# 2. Companies are stockpiling transformers and other components.
# 3. These items cannot be immediately used.
# 4. Companies are buying them because they fear going “to the back of the line.”
# 5. The same pattern appears in individual organizations buying AI tools.
# 6. Organizations are acquiring AI capabilities because everyone else is acquiring them.
# 7. Organizations are purchasing capabilities before they know what to do with them.
# 8. A defining feature of the current AI-investment era is the gap between what organizations have bought and what they are actually using.
#
# **Verification:**
#
# **Claim 1: Companies are stockpiling chips.**
# **Source quote:**
# > "What this has meant is that since the supply of everything that goes into these data centers has been so limited, companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use."
#
# > "If Nvidia says the latest batch of HB200's is ready to purchase, these companies are compelled to buy them even if they don't actually have space to put them yet."
#
# **Comparison:** Supported in substance. The source does not use the word “stockpiling,” but it does describe companies buying chips as soon as available even without immediate space to use them.
#
# ---
#
# **Claim 2: Companies are stockpiling transformers and other components.**
# **Source quote:**
# > "In a typical data center, the transformers, power supplies, generators, and connecting wires typically take up less than 10% of the total build cost."
#
# > "What this has meant is that since the supply of everything that goes into these data centers has been so limited, companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use."
#
# > "The same goes for other components like cooling or energy supplies. Even if they don't have anywhere to use them right now, they are motivated to buy them just in case."
#
# **Comparison:** Partially supported. The source clearly says companies are buying components early and before immediate use. But it does not specifically say companies are stockpiling transformers. “Components” is supported; “transformers” is an extra specificity the source does not directly assign to the stockpiling behavior.
#
# ---
#
# **Claim 3: These items cannot be immediately used.**
# **Source quote:**
# > "companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use."
#
# > "these companies are compelled to buy them even if they don't actually have space to put them yet."
#
# > "Even if they don't have anywhere to use them right now, they are motivated to buy them just in case."
#
# **Comparison:** Supported.
#
# ---
#
# **Claim 4: Companies are buying them because they fear going “to the back of the line.”**
# **Source quote:**
# > "Because if they don't, then they will have to go to the back of the line again."
#
# **Comparison:** Supported in substance. The pitch’s “terrified” is more dramatic than the source, but the underlying reason is explicitly stated.
#
# ---
#
# **Claim 5: The same pattern appears in individual organizations buying AI tools.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported by the source. This is a scope extension from hyperscale data-center procurement to “individual organizations” and AI-tool buying generally.
#
# ---
#
# **Claim 6: Organizations are acquiring AI capabilities because everyone else is acquiring them.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported by the source. This reads as the pitch author’s interpretation/generalization, not something the source establishes.
#
# ---
#
# **Claim 7: Organizations are purchasing capabilities before they know what to do with them.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported directly. The source says companies buy infrastructure before they can deploy it, not before they know what to do with it.
#
# ---
#
# **Claim 8: A defining feature of the current AI-investment era is the gap between what organizations have bought and what they are actually using.**
# **Source quote:**
# > "companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use."
#
# > "there will be a buyer ready for it, even if it does end up sitting in a warehouse for a few months."
#
# **Comparison:** Partially supported as an interpretation. The source supports a gap between purchase and use in this infrastructure context. It does not call that gap “the defining feature of this era,” nor does it generalize it to organizations broadly.
#
# **Overall fidelity:** Qualified pass. The source supports the core procurement-under-constraint story, but the pitch broadens it into a general story about organizational AI-tool buying and motivations that the source does not document.
#
# =================
# Pitch 2: The accounting fiction eating AI strategy
# =================
#
# **Claims identified:**
#
# 1. Tech companies are depreciating AI hardware over six years.
# 2. Those same companies are also claiming next year’s models will make this year’s obsolete.
# 3. When energy costs rise, older GPU racks become e-waste faster than accounting schedules imply.
# 4. Reported/“spreadsheet” compute capacity can diverge from operational reality.
# 5. Organizations relying on reported financials for AI investment decisions are seeing numbers that overstate what is really there.
#
# **Verification:**
#
# **Claim 1: Tech companies are depreciating AI hardware over six years.**
# **Source quote:**
# > "The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years"
#
# **Comparison:** Supported.
#
# ---
#
# **Claim 2: Those same companies are also claiming next year’s models will make this year’s obsolete.**
# **Source quote:**
# > "They are depreciating their hardware over six years while claiming next year's models will render this year's completely obsolete."
#
# **Comparison:** Directly supported.
#
# ---
#
# **Claim 3: When energy costs rise, older GPU racks become e-waste faster than accounting schedules imply.**
# **Source quote:**
# > "On the other end of the spectrum, the depreciation of chips already in service becomes worse the higher energy prices get."
#
# > "If energy prices are very low, it can remain worth it to run older, less efficient hardware, even if it uses much more energy to achieve the same thing. But as energy prices have increased, those margins can be squeezed to the point where it costs more to run a server in energy inputs alone, than it could be rented out for. At that point, multi-million dollar racks of last year's cuttingedge hardware effectively become e-waste."
#
# > "The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years when in reality they would be lucky to stay operationally viable for 3 years."
#
# **Comparison:** Supported in substance. “Faster than the books admit” is a rhetorical restatement of the mismatch between six-year depreciation and shorter operational usefulness.
#
# ---
#
# **Claim 4: Reported/“spreadsheet” compute capacity can diverge from operational reality.**
# **Source quote:**
# No corresponding passage using “compute capacity” this way.
#
# Relevant nearby passages:
# > "By stretching out depreciation for longer than reasonable, service life of these cards makes expenses look better than they really should be for the companies that make up a majority of Nvidia's demand."
#
# > "The point was if companies like Microsoft, Oracle, and Meta had more honest accounting, it would make their profits look worse"
#
# **Comparison:** Only partially supported. The source is about expenses, profits, and accounting presentation, not a direct mismatch between reported compute capacity and operational compute capacity. The pitch shifts from financial reporting to a broader asset-capability framing.
#
# ---
#
# **Claim 5: Organizations relying on reported financials for AI investment decisions are seeing numbers that overstate what is really there.**
# **Source quote:**
# > "By stretching out depreciation for longer than reasonable, service life of these cards makes expenses look better than they really should be"
#
# > "if companies like Microsoft, Oracle, and Meta had more honest accounting, it would make their profits look worse"
#
# **Comparison:** Partially supported. The source does support that accounting can make results “look better” than they should. But it does not discuss “any organization” using reported financials, nor does it say the numbers overstate “what's actually there.” That is a broader implication drawn by the pitch.
#
# **Overall fidelity:** Qualified pass. The central accounting critique is faithful to the source, but the pitch broadens it from reported profits/expenses at major tech firms to a wider claim about usable compute and organizational decision-making.
#
# =================
# Pitch 3: The boring stuff is the binding constraint
# =================
#
# **Claims identified:**
#
# 1. The AI conversation is dominated by chips, models, and capabilities.
# 2. Two fully built data centers near Nvidia headquarters are idle.
# 3. They are idle because the local utility has not caught up.
# 4. Power infrastructure is the real bottleneck.
# 5. That power bottleneck includes transformers.
# 6. That power bottleneck includes grid connections.
# 7. That power bottleneck includes years of permitting.
# 8. This same pattern holds at smaller organizational scale.
# 9. At smaller scale, organizations focus on model choice while real constraints are data quality, integration, and change management.
# 10. Those real constraints go unexamined because they are unglamorous.
# 11. The exciting question crowds out the important one.
#
# **Verification:**
#
# **Claim 1: The AI conversation is dominated by chips, models, and capabilities.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not directly supported. This is framing added by the pitch.
#
# ---
#
# **Claim 2: Two fully built data centers near Nvidia headquarters are idle.**
# **Source quote:**
# > "there are actually two new fully fit out data centers just up the road from Nvidia's headquarters in Santa Clara that are sitting completely offline"
#
# **Comparison:** Directly supported.
#
# ---
#
# **Claim 3: They are idle because the local utility has not caught up.**
# **Source quote:**
# > "because they are waiting for local utilities to catch up."
#
# **Comparison:** Directly supported.
#
# ---
#
# **Claim 4: Power infrastructure is the real bottleneck.**
# **Source quote:**
# > "According to industry analysis, the biggest bottleneck facing new data centers today is not necessarily in the advanced computer chips to run their models, but rather in getting the electrical infrastructure to support it. Power has become the realworld constraint."
#
# **Comparison:** Directly supported.
#
# ---
#
# **Claim 5: That power bottleneck includes transformers.**
# **Source quote:**
# > "In a typical data center, the transformers, power supplies, generators, and connecting wires typically take up less than 10% of the total build cost. But nothing can happen until those components are in place."
#
# **Comparison:** Supported.
#
# ---
#
# **Claim 6: That power bottleneck includes grid connections.**
# **Source quote:**
# Relevant passages:
# > "getting the electrical infrastructure to support it"
#
# > "they are waiting for local utilities to catch up."
#
# > "most data centers get their energy directly from the local energy grid"
#
# **Comparison:** Supported in substance, though “grid connections” is not stated in those exact words.
#
# ---
#
# **Claim 7: That power bottleneck includes years of permitting.**
# **Source quote:**
# No corresponding passage.
#
# Possible nearby material:
# > "Push back from communities who say they don't want data centers in their backyards."
#
# **Comparison:** Not supported. The source mentions community pushback and delays, but not “years of permitting.”
#
# ---
#
# **Claim 8: This same pattern holds at smaller organizational scale.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported directly. This is the pitch author’s analogy.
#
# ---
#
# **Claim 9: At smaller scale, organizations focus on model choice while real constraints are data quality, integration, and change management.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported by the source. This is extrapolation into a different context.
#
# ---
#
# **Claim 10: Those real constraints go unexamined because they are unglamorous.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not supported directly. This is interpretive framing.
#
# ---
#
# **Claim 11: The exciting question crowds out the important one.**
# **Source quote:**
# No corresponding passage.
#
# **Comparison:** Not source-supported as a finding; this is rhetorical interpretation.
#
# **Overall fidelity:** Qualified pass. The source clearly supports the idle-data-center example and the claim that power infrastructure is the key bottleneck, but the pitch adds broader commentary about AI discourse and smaller-scale organizational constraints that goes beyond the source.
#
# ######################################################################
#   BATCH 3
# ######################################################################
#
# ## Verdicts summary for this batch
#
# * Pitch 1: The grid is the constraint — Qualified pass. It accurately cites the offline data-center example and the source’s “power is the constraint” theme, but it broadens that into a claim about organizational AI integration that the source itself does not make.
# * Pitch 2: Buying in anticipation, not in need — Qualified pass. The bullwhip-effect description is faithful to the source, while the extension to general organizational AI adoption is an unsourced but fairly clear analogy.
# * Pitch 3: The 6-year fiction — Fail. It starts from a real depreciation claim in the source, but then overstates it into “the economics wouldn’t work” and “necessary fiction,” which the source does not say.
#
# =================
# Pitch 1: The grid is the constraint
# =================
#
# **Claims identified:**
# 1. Everyone debates which AI model to use.
# 2. Everyone debates which vendor to choose.
# 3. Everyone debates which use cases to prioritize.
# 4. Two fully built data centers near Nvidia’s headquarters are sitting offline waiting for the power company.
# 5. The bottleneck in organizational AI is not the model.
# 6. The bottleneck in organizational AI is integration infrastructure.
# 7. That integration infrastructure is “nobody wants to fund.”
# 8. The organizations getting value are the ones that treated the “plumbing” as the project, not the afterthought.
#
# **Verification:**
#
# **Claim 1: Everyone debates which AI model to use.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 2: Everyone debates which vendor to choose.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 3: Everyone debates which use cases to prioritize.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 4: Two fully built data centers near Nvidia’s headquarters are sitting offline waiting for the power company.**
# **Source quote:** “there are actually two new fully fit out data centers just up the road from Nvidia's headquarters in Santa Clara that are sitting completely offline because they are waiting for local utilities to catch up.”
# **Assessment:** Substantively accurate. “Power company” is a looser paraphrase of “local utilities,” but the meaning is close.
#
# **Claim 5: The bottleneck in organizational AI is not the model.**
# **Source quote:** “According to industry analysis, the biggest bottleneck facing new data centers today is not necessarily in the advanced computer chips to run their models, but rather in getting the electrical infrastructure to support it. Power has become the realworld constraint.”
# **Assessment:** The source supports this for **new data centers**, not for “organizational AI” generally. This is a scope shift from infrastructure buildout to broad organizational AI implementation.
#
# **Claim 6: The bottleneck in organizational AI is integration infrastructure.**
# **Source quote:** “According to industry analysis, the biggest bottleneck facing new data centers today is not necessarily in the advanced computer chips to run their models, but rather in getting the electrical infrastructure to support it.”
# **Assessment:** The source says **electrical infrastructure for data centers** is the bottleneck. It does not discuss “integration infrastructure” inside organizations. This is an extrapolation, not a source-backed finding.
#
# **Claim 7: That integration infrastructure is ‘nobody wants to fund.’**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 8: The organizations getting value are the ones that treated the ‘plumbing’ as the project, not the afterthought.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Overall fidelity:** Qualified pass. The pitch accurately uses a real source example and preserves the source’s narrower point that power/electrical infrastructure is a key constraint. But it then expands that into a broad lesson about organizational AI integration and successful organizations, which the source does not itself establish.
#
# =================
# Pitch 2: Buying in anticipation, not in need
# =================
#
# **Claims identified:**
# 1. The material describes a bullwhip effect in GPU supply chains.
# 2. Companies are buying chips the moment they are available.
# 3. They are not buying them because they have immediate use for them.
# 4. They are buying them because waiting means losing their place in line.
# 5. The same pattern shows up in organizational AI adoption.
# 6. Teams acquire tools, train models, and build capabilities in anticipation of future needs.
# 7. They do this rather than in response to needs they currently have.
# 8. The risk is ending up with expensive capabilities optimized for imagined use cases instead of real ones.
#
# **Verification:**
#
# **Claim 1: The material describes a bullwhip effect in GPU supply chains.**
# **Source quote:** “In industrial planning, this is called the bullwhip effect.”
# **Assessment:** Accurate.
#
# **Claim 2: Companies are buying chips the moment they are available.**
# **Source quote:** “companies are buying everything they can as soon as they can”
# and
# “If Nvidia says the latest batch of HB200's is ready to purchase, these companies are compelled to buy them”
# **Assessment:** Accurate.
#
# **Claim 3: They are not buying them because they have immediate use for them.**
# **Source quote:** “companies are buying everything they can as soon as they can, even if it takes a long time to actually be put into use.”
# and
# “These companies are compelled to buy them even if they don't actually have space to put them yet.”
# **Assessment:** Accurate.
#
# **Claim 4: They are buying them because waiting means losing their place in line.**
# **Source quote:** “Because if they don't, then they will have to go to the back of the line again.”
# **Assessment:** Accurate.
#
# **Claim 5: The same pattern shows up in organizational AI adoption.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source; this is an analogy the pitch introduces.
#
# **Claim 6: Teams acquire tools, train models, and build capabilities in anticipation of future needs.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 7: They do this rather than in response to needs they currently have.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 8: The risk is ending up with expensive capabilities optimized for imagined use cases instead of real ones.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Overall fidelity:** Qualified pass. The supply-chain portion is faithful and well grounded in the source. The move from GPU/data-center purchasing behavior to general organizational AI adoption is not supported by the raw material, but it reads as the pitch’s own framework rather than a false quote of the source.
#
# =================
# Pitch 3: The 6-year fiction
# =================
#
# **Claims identified:**
# 1. Companies are depreciating AI hardware over 6 years.
# 2. That hardware might stay viable for only 3 years.
# 3. If those companies accounted honestly, the economics would not work.
# 4. This is not fraud.
# 5. It is a necessary fiction.
# 6. That fiction makes investment possible.
# 7. Honest numbers do not justify the investment.
# 8. Organizations implementing AI are implicitly assuming some depreciation schedule for their own systems.
# 9. If that timeline were cut in half, their business case would change materially.
#
# **Verification:**
#
# **Claim 1: Companies are depreciating AI hardware over 6 years.**
# **Source quote:** “The industry standard amongst the big tech companies is to depreciate these GPUs over 6 years”
# **Assessment:** Mostly accurate, but slightly broadened. The source says **big tech companies** and specifically **these GPUs**, not all “companies” and all “AI hardware.”
#
# **Claim 2: That hardware might stay viable for only 3 years.**
# **Source quote:** “when in reality they would be lucky to stay operationally viable for 3 years.”
# **Assessment:** Accurate.
#
# **Claim 3: If those companies accounted honestly, the economics would not work.**
# **Source quote:** “The point was if companies like Microsoft, Oracle, and Meta had more honest accounting, it would make their profits look worse, which may reduce investor hype around AI investment and ultimately the demand these companies have for even more GPUs coming down the pipe.”
# and
# “if Microsoft is pressured into re-evaluating this accounting standard, they might lose a little bit of profitability on paper”
# **Assessment:** Not supported. The source says more honest accounting would make profits look worse and could reduce hype and demand. It does **not** say the economics “wouldn’t work.”
#
# **Claim 4: This is not fraud.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 5: It is a necessary fiction.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Claim 6: That fiction makes investment possible.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source. The source does not claim this accounting treatment is what makes the investment possible.
#
# **Claim 7: Honest numbers do not justify the investment.**
# **Source quote:** No corresponding passage directly supporting this. The closest passage is: “it would make their profits look worse, which may reduce investor hype around AI investment”
# **Assessment:** Overstatement. The source says honest accounting would worsen reported profitability and might reduce hype; it does not conclude that the investment is unjustified.
#
# **Claim 8: Organizations implementing AI are implicitly assuming some depreciation schedule for their own systems.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source; this is the pitch’s analogy.
#
# **Claim 9: If that timeline were cut in half, their business case would change materially.**
# **Source quote:** No corresponding passage in the raw material.
# **Assessment:** Unsupported by source.
#
# **Overall fidelity:** Fail. The source supports the narrower claim that big tech depreciates GPUs over 6 years despite a much shorter likely useful life, and that more honest accounting would make profits look worse. The pitch turns that into a much stronger claim—that the economics do not work and only survive because of a “necessary fiction”—which the source does not say.
#
# ======================================================================
#   DONE — 3 of 3 batches evaluated for fidelity.
# ======================================================================

# %% [markdown]
# # Run the experiment up to supervisorPrompt1.5
# ## Run the pipeline up to supervisorPrompt

# %%
import time
import re
from datetime import datetime
from phoenix.client.experiments import run_experiment
import anthropic

def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

def extract_final_pitches(output):
    """Extract only the Final Pitches section, stripping all reasoning."""
    marker = "## Final Pitches"
    idx = output.find(marker)
    if idx != -1:
        return output[idx + len(marker):].strip()
    match = re.search(r"##\s*Final\s*Pitches", output, re.IGNORECASE)
    if match:
        return output[match.end():].strip()
    return output.strip()

def full_angle_pipeline(input):
    api_client = anthropic.Anthropic()
    
    # Load prompts
    angle_prompt = read_prompt("angleProposalPrompt1.md")
    supervisor_prompt = read_prompt("supervisorPrompt1.5.md")
    
    # Run angle proposal 3 times, extract only final pitches
    extracted_pitches = []
    for i in range(1, 4):
        print(f"  → Angle proposal {i}/3...")
        if i > 1:
            time.sleep(10)
        message = api_client.messages.create(
            model="claude-opus-4-5-20251101",
            max_tokens=16000,
            system=angle_prompt,
            messages=[{"role": "user", "content": input["raw_material"]}],
        )
        pitches = extract_final_pitches(message.content[0].text)
        extracted_pitches.append(pitches)
        print(f"  ✓ Batch {i} complete")
    
    # Combine extracted pitches into labeled block
    combined = ""
    for i, pitches in enumerate(extracted_pitches, 1):
        combined += f"## Batch {i}\n\n{pitches}\n\n"
    
    # Run supervisor on combined pitches
    print("  → Running supervisor...")
    supervisor_message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=supervisor_prompt,
        messages=[{"role": "user", "content": combined}],
    )
    print("  ✓ Pipeline complete")
    
    return {
        "supervisor_input": combined,
        "supervisor_output": supervisor_message.content[0].text
    }

# ---- CHANGE THIS EACH RUN WHEN NEW DATASET IS EMPLOYED----
run_description = "v1.5 - modded cohesion reviewer 04.06.26"
# --------------------------------

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"full-pipeline-upToSupervisor-{timestamp}"

latest_experiment = run_experiment(
    dataset=dataset,
    task=full_angle_pipeline,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"Experiment: {experiment_name}")
print(f"Description: {run_description}")

# %% [markdown]
# ### Print results for the run above

# %%
for run in latest_experiment["task_runs"]:
    output = run["output"]
    
    # print("=" * 60)
    # print("WHAT THE SUPERVISOR RECEIVED:")
    # print("=" * 60)
    # print(output["supervisor_input"])
    
    # print("\n\n")
    
    print("=" * 60)
    print("WHAT THE SUPERVISOR CHOSE:")
    print("=" * 60)
    print(output["supervisor_output"])

# %%
import sys

# %%
print(sys.executable)

# %% [markdown]
# # Run the experiment for articleGeneratePrompt2.md

# %% [markdown]
# ## Initializing dataset
# (run once)

# %% [markdown]
# ### Load the dataset with samples pitches appended

# %%
# Dataset: raw material + all 3 supervisor-selected pitches
with open("Class_4_test_sample.txt", "r") as f:
    raw_material = f.read()

pitches = [
    {
        "title": "Make it sound dumber on purpose",
        "style": "Contrarian",
        "pitch": """Apple had the technology to make Siri sound human in 2013 but deliberately made it robotic. User satisfaction rose because expectations dropped. This isn't a quirk — it's a design principle most AI products ignore. The Bing harassment disaster, the catbot spectrum from "as an AI language model" to "meow meow meow" — every point on that range is technically correct, but only one manages expectations for *your* use case. The argument: the AI that sounds slightly mechanical, gives one-sentence answers, and stops short of what's possible will outperform the one that impresses on first contact."""
    },
    {
        "title": "Your bot forces the org chart soul-search",
        "style": "Observation",
        "pitch": """Most companies have never articulated their organizational voice, logic, or relationship posture — it emerged by accident across years of output. Building a chatbot forces the question. The LUX document isn't a branding exercise; it's archaeology. You're discovering what your company actually believes by trying to make a machine embody it. Industrial firms, nonprofits, anyone who's "just doing the work" — they all hit this wall when the bot needs to talk."""
    },
    {
        "title": "Stop iterating on the chat box",
        "style": "Philosopher",
        "pitch": """We're in horseless carriage territory — bolting AI onto document-writing paradigms because that's what we know. The blank text input isn't intimidating because it lacks examples; it's the wrong interface category entirely. The material shows experiments in coordinate-plane text editors, infinite canvas generators, and comic book makers. The argument: the practitioners who break through aren't optimizing chat UX — they're inventing interaction paradigms that don't exist yet."""
    }
]

article_dataset = client.datasets.create_dataset(
    name="article_gen_raw_plus_pitchTest",
    dataset_description="Supervisor-selected pitches plus raw material from Class 4 for testing article generator prompt",
    examples=[
        {
            "input": {
                "raw_material": raw_material,
                "pitch": p["pitch"],
                "title": p["title"],
                "style": p["style"]
            },
            "output": {},
            "metadata": {"title": p["title"], "style": p["style"]}
        }
        for p in pitches
    ]
)
print(f"Created dataset: {article_dataset.id}")

# %% [markdown]
# ### Deleting dataset for modifications

# %%
dataset_name = "article_gen_raw_plus_pitchTest"

try:
    # 1. Fetch the dataset to get its ID (this part of the SDK works)
    ds = client.datasets.get_dataset(dataset=dataset_name)
    
    # 2. Use the internal client to send a raw DELETE request
    # This automatically uses the headers and API keys you've already set up
    response = client._client.delete(f"v1/datasets/{ds.id}")
    
    if response.status_code in [200, 204]:
        print(f"Successfully deleted: {dataset_name}")
    else:
        print(f"Failed: {response.status_code} - {response.text}")
except Exception as e:
    print(f"Dataset not found or already deleted: {e}")

# %% [markdown]
# ### Load dataset (Run every time)

# %%
article_dataset = client.datasets.get_dataset(dataset="article_gen_raw_plus_pitchTest")
print(f"Loaded dataset: {article_dataset.id}")

# %% [markdown]
# ## Run the experiment and save the output

# %%
import os
import anthropic
from datetime import datetime
from phoenix.client.experiments import run_experiment


def read_prompt(filename):
    with open(f"prompts/{filename}", "r") as f:
        return f.read()

article_prompt = read_prompt("articleGeneratePrompt2.md")

def run_article_generator(example):
    api_client = anthropic.Anthropic()
    
    pitch_block = f"[{example['input']['title']}] | Style: {example['input']['style']}\n{example['input']['pitch']}"
    user_content = f"## Selected Pitch\n{pitch_block}\n\n## Raw Material\n{example['input']['raw_material']}"
    
    print(f"  → Generating articles for: {example['input']['title']}...")
    message = api_client.messages.create(
        model="claude-opus-4-5-20251101",
        max_tokens=16000,
        system=article_prompt,
        messages=[{"role": "user", "content": user_content}],
    )
    print(f"  ✓ Done")
    
    return {"article_versions": message.content[0].text}

# Setup Experiment Metadata
run_description = "v1 - initial article generator test"
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
experiment_name = f"article-generator-{timestamp}"

# Execute experiment
article_experiment = run_experiment(
    dataset=article_dataset,
    task=run_article_generator,
    experiment_name=experiment_name,
    experiment_description=run_description,
    timeout=1000
)

print(f"\nExperiment: {experiment_name}")
print(f"Description: {run_description}")

# %% [markdown]
# ### Print run output

# %%
import re

examples = article_dataset.examples
example_lookup = {ex["id"]: ex for ex in examples}

# Bird's eye view
print("EXPERIMENT SUMMARY")
print("=" * 70)
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print(f"\nRUN {i+1}: {title} ({style})")
    approaches = re.findall(r'\*\*Delivery approach:\*\*\s*(.+)', output)
    for j, approach in enumerate(approaches, 1):
        print(f"  Version {j}: {approach}")

print("\n" + "=" * 70 + "\n")

# Full outputs
for i, run in enumerate(article_experiment["task_runs"]):
    example = example_lookup.get(run["dataset_example_id"])
    title = example["input"]["title"] if example else f"Run {i+1}"
    style = example["input"]["style"] if example else ""
    output = run["output"]["article_versions"]
    
    print("=" * 70)
    print(f"RUN {i+1}: {title} ({style})")
    print("=" * 70)
    print(output)
    print("\n" + "#" * 70 + "\n")

# %% [markdown]
# ### Check system prompt
